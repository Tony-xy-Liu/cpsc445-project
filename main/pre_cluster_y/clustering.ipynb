# %%
import os
import numpy as np
import pandas as pd
from sklearnex import patch_sklearn
patch_sklearn()

from local.caching import load, save
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
cosdis_save = "metabolite_cos_dist"
cosdis = load(cosdis_save)
# Out:
# recovering & decompressing cached data from [{WORKSPACE}/main/pre_cluster_y/cache/metabolite_cos_dist.pkl.gz]

# %%
from plotly import graph_objects as go, subplots as sp
from sklearn.neighbors import KNeighborsClassifier

# settings

axis_col = 'rgba(0, 0, 0, 0.15)'
no_col = 'rgba(0, 0, 0, 0)'
axis_desc: dict = dict(linecolor=no_col, gridcolor=axis_col, zerolinecolor=axis_col, zerolinewidth=1)
layout = dict(
    autosize=False,
    width=1400,
    height=650,
    margin=dict(
        l=25, r=25, b=25, t=50, pad=5
    ),
    # paper_bgcolor="white",
    font_family="Times New Roman",
    font_color="black",
    font_size=20,
    plot_bgcolor='white',
    xaxis=axis_desc,
    yaxis=axis_desc,
    xaxis2=axis_desc,
    yaxis2=axis_desc,
)

# %%
positions = load("tsne_p100")
# Out:
# recovering & decompressing cached data from [{WORKSPACE}/main/pre_cluster_y/cache/tsne_p100.pkl.gz]

# %%
from hdbscan import HDBSCAN

cosdis_d = cosdis.astype(np.double)
def try_one(e: float):
    model = HDBSCAN(min_samples=5, metric="precomputed", core_dist_n_jobs=12,
        # alpha=float(alpha),
        cluster_selection_epsilon=float(e)
    )
    model.fit(cosdis_d)
    group_assignments = model.labels_
    groups = {}
    for i, g in enumerate(group_assignments):
        groups[g] = groups.get(g, []) + [i]
    sgroups = sorted(groups.items(), key=lambda t: len(t[1]), reverse=True)

    def make_traces():
        s, o = 2, 0.5
        return [
            go.Scatter(
                x=[x for i, (x, y) in enumerate(positions) if i in members],
                y=[y for i, (x, y) in enumerate(positions) if i in members],
                mode='markers',
                marker=dict(size=s,opacity=o,color="#555555") if g==-1 or len(members)<5 else dict(size=s, opacity=o),
                name=f"{g}"
            )
        for j, (g, members) in enumerate(sgroups)]

    fig = sp.make_subplots(
        rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, horizontal_spacing=0.02,
        # x_title="% Completeness"
    )

    for i, tr in enumerate(make_traces()):
        fig.add_trace(tr, row=1, col=1)
    _layout = layout.copy()
    _layout.update(dict(
        xaxis=dict(title="", **axis_desc),
        yaxis=dict(title="", **axis_desc),
        width=500,
        height=450,
    ))
    fig.update_annotations(font_size=24)
    fig.update_layout(go.Layout(title=f"{e}", **_layout))
    fig.show()

    return sgroups

labels = []
for v in [0, 0.05, 0.07, 0.1, 0.2]:
    labels.append(try_one(v))

# %%
df: pd.DataFrame = load('biocyc_metabolite_usage', alt_workspace="../prep/")
min_freq = 0.01
indexes_kept = [i for i, v in enumerate(df.sum(axis=0)) if v >= len(df)*min_freq]
fdf = df.iloc[:, indexes_kept]
fdf.shape, df.shape
# Out:
# recovering & decompressing cached data from [../prep/cache/biocyc_metabolite_usage.pkl.gz]
# ((19999, 9849), (19999, 32681))

# %%
for g, members in labels[2]:
    if g == -1: continue
    print(len(members))
    for m in members:
        print(fdf.columns[m])
    # print(g, len(members))
    print()
    print("#"*150)
    print()
# Out:
# 1059
# i_UTP
# i_PPI
# i_GLC-1-P
# i_PROTON
# i_Hydroxymethylbilane-Synthase-ES2
# i_PORPHOBILINOGEN
# i_HYDROGEN-PEROXIDE
# i_MET
# i_WATER
# i_CPD0-2351
# i_NAD
# i_Dihydro-Lipoyl-Proteins
# i_NADH
# i_2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE
# i_CPD-9451
# i_S-ADENOSYLMETHIONINE
# i_ATP
# i_Acceptor
# i_Hydroxymethylbilane-Synthase-ES3
# i_Pi
# i_Oxo-glutarate-dehydrogenase-DH-lipoyl
# i_DIHYDROXY-ACETONE-PHOSPHATE
# i_GTP
# i_L-CITRULLINE
# i_CARBAMOYL-P
# i_Single-Stranded-DNAs
# i_Ribonucleoside-Triphosphates
# i_Hydroxymethylbilane-Synthase-ES4
# i_23S-rRNA-guanine-2551
# i_PROTEIN-LIPOYLLYSINE
# i_DIHYDROLIPOYL-GCVH
# i_NADP
# i_NADPH
# i_CPD-19169
# i_CO-A
# i_3-CARBOXY-3-HYDROXY-ISOCAPROATE
# i_G3P
# i_2-PG
# i_FUM
# i_R-3-Hydroxypalmitoyl-ACPs
# i_L-ASPARTATE
# i_O-UREIDOHOMOSERINE
# i_Protein-Histidines
# i_23-DIPHOSPHOGLYCERATE
# i_Protein-pi-phospho-L-histidines
# i_CPD-16758
# i_SUC
# i_ACETYL-COA
# i_NAD-P-OR-NOP
# i_HYPOXANTHINE
# i_E-
# i_ETR-Quinones
# i_Beta-hydroxydecanoyl-ACPs
# i_UDP-N-ACETYL-D-GLUCOSAMINE
# i_OXALACETIC_ACID
# i_FRUCTOSE-6P
# i_CPD-15709
# i_ETF-Oxidized
# i_CPD-10267
# i_7-8-DIHYDROPTEROATE
# i_GLT
# i_L-GLUTAMATE-5-P
# i_L-Cysteine-Desulfurase-persulfide
# i_Donor-H2
# i_General-Protein-Substrates
# i_CIS-DELTA3-ENOYL-COA
# i_N5-Formyl-THF-Glu-N
# i_CPD-196
# i_Pyruvate-dehydrogenase-acetylDHlipoyl
# i_ERYTHROSE-4P
# i_THF-GLU-N
# i_AMMONIUM
# i_AMINOMETHYLDIHYDROLIPOYL-GCVH
# i_METHYLENE-THF-GLU-N
# i_L-ARGININO-SUCCINATE
# i_MESO-DIAMINOPIMELATE
# i_LYS
# i_HEXANOYL-COA
# i_HYDROXYMETHYLBILANE
# i_RIBOSE-5P
# i_RIBULOSE-5P
# i_CPD-15436
# i_PYRUVATE
# i_Pyruvate-dehydrogenase-lipoate
# i_CPD-8180
# i_CANAVANINOSUCCINATE
# i_GLY
# i_2-ALPHA-HYDROXYETHYL-THPP
# i_CPD-19144
# i_2-KETOGLUTARATE
# i_Peptides-with-Leader-Sequence
# i_Ubiquinones
# i_2-KETO-ISOVALERATE
# i_UDP-N-ACETYLMURAMATE
# i_HS
# i_THREO-DS-ISO-CITRATE
# i_CPD-19171
# i_CDPDIACYLGLYCEROL
# i_SER
# i_R-3-hydroxymyristoyl-ACPs
# i_CIS-ACONITATE
# i_3-P-HYDROXYPYRUVATE
# i_ADP
# i_TYR
# i_3-oxo-palmitoyl-ACPs
# i_CARBAMYUL-L-ASPARTATE
# i_HOMO-CYS
# i_5-METHYL-THF-GLU-N
# i_CPD0-1162
# i_CPD0-1158
# i_CPD-7221
# i_CPD-7222
# i_L-ALPHA-ALANINE
# i_Supercoiled-Duplex-DNAs
# i_B-KETOACYL-ACP
# i_3-oxo-stearoyl-ACPs
# i_CTP
# i_CPD-12377
# i_ACETYLSERINE
# i_carboxybiotin-L-lysine-in-BCCP-dimers
# i_ACYL-SN-GLYCEROL-3P
# i_THIAMINE-P
# i_PHENYL-PYRUVATE
# i_2-ACETO-LACTATE
# i_5-PHOSPHO-RIBOSYL-GLYCINEAMIDE
# i_FORMYL-THF-GLU-N
# i_NADH-P-OR-NOP
# i_HCO3
# i_H2CO3
# i_DEAMIDO-NAD
# i_PROT-CYS
# i_GDP
# i_GMP
# i_3-oxo-myristoyl-ACPs
# i_CPD-15818
# i_D-Ribofuranose
# i_5-PHOSPHORIBOSYL-N-FORMYLGLYCINEAMIDINE
# i_GLN
# i_DELTA3-ISOPENTENYL-PP
# i_CPD-19833
# i_LEU
# i_Octanoyl-ACPs
# i_Protein-S-Acetyl-Cysteines
# i_PRPP
# i_GUANOSINE-5DP-3DP
# i_DEPHOSPHO-COA
# i_CYS
# i_METHIONYL-PEPTIDE
# i_FORMYL-L-METHIONYL-PEPTIDE
# i_3-Oxo-octanoyl-ACPs
# i_GDP-TP
# i_Reduced-NrdH-Proteins
# i_DGDP
# i_Charged-fMET-tRNAs
# i_3-oxo-decanoyl-ACPs
# i_UDP
# i_Red-Thioredoxin
# i_L-DELTA1-PYRROLINE_5-CARBOXYLATE
# i_ARG-tRNAs
# i_ARG
# i_CHORISMATE
# i_RNASE-III-MRNA-PROCESSING-SUBSTRATE
# i_AMP
# i_UDP-OHMYR-ACETYLGLUCOSAMINE
# i_CPD0-2106
# i_PRO
# i_PHOSPHORIBOSYL-AMP
# i_CPD0-2108
# i_L-3-HYDROXYACYL-COA
# i_16S-rRNA-adenine1518-adenine1519
# i_DIHYDROXY-BUTANONE-P
# i_AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE
# i_3-oxo-dodecanoyl-ACPs
# i_DEOXYXYLULOSE-5P
# i_1-AMINO-PROPAN-2-ONE-3-PHOSPHATE
# i_PHOSPHORIBOSYL-ATP
# i_4-PHOSPHONOOXY-THREONINE
# i_Acetoacetyl-ACPs
# i_Palmitoleoyl-ACPs
# i_PREPHENATE
# i_PHE-tRNAs
# i_PHOSPHORIBOSYL-FORMIMINO-AICAR-P
# i_D-glucopyranose-6-phosphate
# i_CPD-8625
# i_CPD-8624
# i_Deoxy-Ribonucleoside-Triphosphates
# i_PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE
# i_3-oxo-hexanoyl-ACPs
# i_CPD-13357
# i_CDP
# i_Phosphoglucomutase
# i_Phosphorylated-phosphoglucomutase
# i_ALPHA-GLUCOSE-16-BISPHOSPHATE
# i_DGTP
# i_PHOSPHO-ENOL-PYRUVATE
# i_THR-tRNAs
# i_THR
# i_BISOHMYR-GLC
# i_L-HISTIDINOL-P
# i_CPD0-2244
# i_MONOMER0-4342
# i_OH-HEXANOYL-COA
# i_CPD-12304
# i_CPD-12303
# i_DNA-6-O-Methyl-Guanines
# i_Octanoylated-Gcv-H
# i_DUMP
# i_AMINO-HYDROXYMETHYL-METHYL-PYR-P
# i_DCMP
# i_IMIDAZOLE-ACETOL-P
# i_CPD-11998
# i_CPD-11997
# i_UMP
# i_Elongation-tRNAMet
# i_AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP
# i_CPD-13575
# i_DNA-Combined-With-Exogenous-DNA
# i_1-KETO-2-METHYLVALERATE
# i_VAL
# i_TMP
# i_Protein-S-methyl-L-cysteine
# i_a-thymine-in-DNA
# i_CPD-19186
# i_ILE-tRNAs
# i_Initiation-tRNAmet
# i_CPD0-1163
# i_THZ-P
# i_FE+2
# i_tRNA-with-7-aminomethyl-7-deazaguanine
# i_C4
# i_CPD0-2121
# i_3-Hydroxy-octanoyl-ACPs
# i_CPD-15244
# i_HISTIDINOL
# i_CPD-13576
# i_HISTIDINAL
# i_XANTHINE
# i_C5
# i_RIBOFLAVIN
# i_Guanine34-in-tRNAs
# i_7-AMINOMETHYL-7-DEAZAGUANINE
# i_Trans-D2-decenoyl-ACPs
# i_GAP
# i_PRO-tRNAs
# i_Ribonucleoside-Diphosphates
# i_5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE
# i_CPD0-2107
# i_TRANS-D2-ENOYL-ACP
# i_D-GLT
# i_CPD0-1456
# i_Dodec-2-enoyl-ACPs
# i_D-GLUCOSAMINE-6-P
# i_GLUCOSAMINE-1P
# i_tRNA-uridines
# i_K-HEXANOYL-COA
# i_CPD0-1096
# i_Phosphorylated-Phosphoglucosamine-Mutase
# i_Phosphoglucosamine-Mutase
# i_CPD-12258
# i_UROPORPHYRINOGEN-III
# i_Diacylglycerol-Prolipoproteins
# i_Phosphoglycerides
# i_DIHYDROPTERIN-CH2OH-PP
# i_P-AMINO-BENZOATE
# i_T2-DECENOYL-COA
# i_2-3-4-Saturated-L-Phosphatidates
# i_OXALO-SUCCINATE
# i_Nucleoside-Triphosphates
# i_1-Acyl-2-Arachidonoyl-Glycerol-P
# i_DEOXY-D-RIBOSE-1-PHOSPHATE
# i_DEOXYINOSINE
# i_CPD-16013
# i_D-ALA-D-ALA
# i_UDP-AAGM-DIAMINOHEPTANEDIOATE
# i_Sulfurated-Sulfur-Acceptors
# i_KDO
# i_Oxo-glutarate-dehydrogenase-lipoyl
# i_tRNA-Containing-5AminoMe-2-ThioUrdines
# i_ASP-tRNAs
# i_CPD-209
# i_ADENYLOSUCC
# i_DUTP
# i_CPD-19839
# i_DNA-containing-abasic-Sites
# i_CPD-22313
# i_P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE
# i_CPD-18238
# i_UDP-AA-GLUTAMATE
# i_CARBAMATE
# i_ADENINE
# i_N-Substituted-Aminoacyl-tRNA
# i_DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE
# i_PROTOPORPHYRIN_IX
# i_XYLULOSE-5-PHOSPHATE
# i_tRNA-containing-5-CarbMeAminome-2-ThioU
# i_DPG
# i_Charged-CYS-tRNAs
# i_CYS-tRNAs
# i_Hydroxymethylbilane-Synthase-Cys
# i_16S-rRNA-guanine-966
# i_Relaxed-DNAs
# i_Negatively-super-coiled-DNAs
# i_CPD0-2105
# i_S-3-HYDROXYBUTANOYL-COA
# i_THYMIDINE
# i_TusA-L-cysteine
# i_VAL-tRNAs
# i_CPD-19168
# i_PANTOTHENATE
# i_2-DEHYDROPANTOATE
# i_N-ACETYL-D-GLUCOSAMINE-1-P
# i_5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE
# i_Decanoyl-ACPs
# i_KDO-8P
# i_L-PANTOATE
# i_Prolipoprotein-Cysteines
# i_TusE-L-cysteine
# i_TusD-Persulfides
# i_DEOXYURIDINE
# i_16S-rRNA-guanine-527
# i_FRUCTOSE-16-DIPHOSPHATE
# i_CPD0-2354
# i_Beta-3-hydroxybutyryl-ACPs
# i_DEHYDROQUINATE
# i_CPD0-2352
# i_DADP
# i_GLN-tRNAs
# i_biotin-L-lysine-in-BCCP-dimers
# i_tRNA-Containing-5MeAminoMe-2-ThioU
# i_L-ASPARTATE-SEMIALDEHYDE
# i_LEU-tRNAs
# i_GLT-tRNAs
# i_GLY-tRNAs
# i_DODECANOATE
# i_PHOSPHORIBULOSYL-FORMIMINO-AICAR-P
# i_CH33ADO
# i_GUANINE
# i_D-form-FeS-Cluster-Scaffold-Proteins
# i_Persulfurated-L-cysteine-desulfurases
# i_3-Hydroxy-Terminated-DNAs
# i_5-Phospho-terminated-DNAs
# i_mnm5GeS2U
# i_DNA-Ligase-L-lysine
# i_TYR-tRNAs
# i_D-ERYTHRO-IMIDAZOLE-GLYCEROL-P
# i_CPD-10330
# i_CPD0-1108
# i_Menaquinones
# i_Lipoprotein-signal-peptide
# i_DNA-Ligase-L-lysine-adenylate
# i_N-formyl-L-methionyl-tRNAfmet
# i_L-methionyl-tRNAfmet
# i_A-5-prime-PP-5-prime-DNA
# i_S-CD-Apo-SP-Complex
# i_DIHYDRONEOPTERIN-P3
# i_Nucleoside-Diphosphates
# i_CPD-11763
# i_CPD-11281
# i_S-CD-S-SP-Complex
# i_DEOXYADENOSINE
# i_Myristoyl-ACPs
# i_mnm5SeP2U
# i_CPD-469
# i_CPD0-2353
# i_TusA-Persulfides
# i_TusD-L-cysteine
# i_CPD0-181
# i_CD-2S-SP-Complex
# i_FE+3
# i_Octadec-2-enoyl-ACPs
# i_OROTATE
# i_D-Ribopyranose
# i_INDOLE
# i_OH-MYRISTOYL
# i_COPROPORPHYRINOGEN_III
# i_IMP
# i_FeS-Cluster-Co-Chaperones
# i_CD-SP-2Fe2S-Complex
# i_Charged-GLT-tRNAs
# i_PALMITATE
# i_tRNA-uridine-38-40
# i_3-DEHYDRO-SHIKIMATE
# i_XANTHOSINE-5-PHOSPHATE
# i_INDOLE-3-GLYCEROL-P
# i_GUANOSINE
# i_CPD-19170
# i_Co-chaperone-SP-2Fe2S-Complex
# i_FeS-Cluster-Chaperones-ATP
# i_ADENOSINE
# i_Palmitoyl-ACPs
# i_2-Octenoyl-ACPs
# i_Apo-FeS-cluster-proteins
# i_Chap-ATP-Co-chaperone-SP-2Fe2S-Complex
# i_CMP
# i_Reduced-2Fe-2S-Ferredoxins
# i_Chap-ADP-apo-SP-Complex
# i_CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P
# i_Release-factor-L-glutamine
# i_Saturated-Fatty-Acyl-ACPs
# i_ASN
# i_HIS-tRNAs
# i_Butanoyl-ACPs
# i_a-pyruvate-dehydrogenase-E2-protein-Nsup
# i_Oxidized-2Fe-2S-Ferredoxins
# i_5-10-METHENYL-THF-GLU-N
# i_PYRROLINE-HYDROXY-CARBOXYLATE
# i_DNA-Segment-Placeholder
# i_DNA-Segment-in-Reverse-Orientations
# i_OLEATE-CPD
# i_CPD-18118
# i_SUPER-OXIDE
# i_XANTHOSINE
# i_N-5-PHOSPHORIBOSYL-ANTHRANILATE
# i_LYS-tRNAs
# i_a-2-oxoglutarate-dehydrogenase-E2-protei
# i_BISOHMYR-GLUCOSAMINYL-1P
# i_TDP
# i_Crotonyl-ACPs
# i_DUDP
# i_DCDP
# i_Octanoylated-domains
# i_ALA-tRNAs
# i_3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P
# i_Hex-2-enoyl-ACPs
# i_AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE
# i_CPD-22307
# i_tRNA-2-thiouridine34
# i_DATP
# i_2-Hexadecenoyl-ACPs
# i_DIHYDROFOLATE-GLU-N
# i_Dodecanoyl-ACPs
# i_DNA-with-Uracils
# i_TRP-tRNAs
# i_CPD0-2123
# i_CPD-16954
# i_CPD-16953
# i_CPD-7100
# i_Tetradec-2-enoyl-ACPs
# i_tRNA-adenine-37
# i_CPD-15435
# i_7-CYANO-7-DEAZAGUANINE
# i_CPD-19167
# i_3OH-4P-OH-ALPHA-KETOBUTYRATE
# i_BIOTIN
# i_BCCP-L-lysine
# i_Hexanoyl-ACPs
# i_R-3-hydroxyhexanoyl-ACPs
# i_CPD-19753
# i_ALLO-THR
# i_UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE
# i_SHIKIMATE-5P
# i_tRNA-Sec
# i_CPD-19172
# i_QUINOLINATE
# i_CPD0-2554
# i_SER-tRNAs
# i_tRNAs-containing-epoxy-quenosine
# i_L-ALPHA-AMINO-EPSILON-KETO-PIMELATE
# i_ASN-tRNAs
# i_DIHYDRO-NEO-PTERIN
# i_16S-rRNA-cytidine1402
# i_OROTIDINE-5-PHOSPHATE
# i_ssRNAs
# i_DIMETHYL-D-RIBITYL-LUMAZINE
# i_L-BETA-ASPARTYL-P
# i_UDP-OHMYR-GLUCOSAMINE
# i_PANTETHEINE-P
# i_CPD-602
# i_AICAR
# i_ERYTHRONATE-4P
# i_PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE
# i_DETHIOBIOTIN
# i_CO3
# i_5-P-BETA-D-RIBOSYL-AMINE
# i_GLUTAMATE-1-SEMIALDEHYDE
# i_CD-S-SP-Complex
# i_RNA-DNA-hybrids
# i_16S-rRNA-uracil1498
# i_BCCP-biotin-L-lysine
# i_R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE
# i_Holo-Hydroxymethylbilane-Synthase
# i_N-ACETYL-GLUTAMYL-P
# i_Hydroxymethylbilane-Synthase-ES
# i_Pyruvate-dehydrogenase-dihydrolipoate
# i_3-ENOLPYRUVYL-SHIKIMATE-5P
# i_ACETYL-GLU
# i_L-Cysteine-Desulfurases
# i_L-glutamyl-tRNAGln
# i_5-Phosphooxy-L-glutamyl-tRNAGlln
# i_L-aspartyl-tRNAAsn
# i_4-Phosphooxy-L-aspartyl-tRNAAsn
# i_TETRADECANOYL-COA
# i_Demethylated-methyl-acceptors
# i_LINOLENIC_ACID
# i_CPD-18348
# i_CPD-10269
# i_1-PALMITOYLGLYCEROL-3-PHOSPHATE
# i_CPD-14927
# i_CPD-18346
# i_CPD-14268
# i_CPD-9247
# i_CPD-17371
# i_CPD-17373
# i_CPD-17372
# i_CPD-17641
# i_CPD-17640
# i_Cis-vaccenoyl-ACPs
# i_CPD-3617
# i_CPD-18379
# i_18-HYDROXYOLEATE
# i_CPD-17370
# i_CPD-17273
# i_CPD0-2113
# i_R2OH-Straight-Chain-234-Sat-FA
# i_LINOLEIC_ACID
# i_1-Stearoyl-L-Phosphatidate
# i_16-HYDROXYPALMITATE
# i_CPD-9245
# i_3-Methyl-Saturated-Fatty-Acids
# i_PRISTANATE
# i_2-Palmitoyl-L-Phosphatidate
# i_CPD0-1423
# i_Odd-Straight-Chain-234-Sat-FA
# i_L-1-LYSOPHOSPHATIDATE
# i_CPD-8268
# i_2-Me-Branched-234-Sat-FA
# i_CPD-17319
# i_1-Alkyl-2-acyl-glycerol-3-phosphate
# i_5Z8Z11Z14Z17Z-EICOSAPENTAENOATE
# i_CPD-17637
# i_Saturated-2-Lysophosphatidates
# i_OCTADEC-9-ENE-118-DIOIC-ACID
# i_CPD-17624
# o_HOMO-CYS
# o_CPD-12575
# o_PPI
# o_PROTON
# o_CO-A
# o_AMMONIUM
# o_Hydroxymethylbilane-Synthase-ES3
# o_WATER
# o_CPD0-2352
# o_Nucleoside-Monophosphates
# o_NADH
# o_NAD
# o_2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE
# o_CPD-9451
# o_ADENOSYL-HOMO-CYS
# o_ADP
# o_HIS
# o_Donor-H2
# o_Hydroxymethylbilane-Synthase-ES4
# o_Pi
# o_Oxo-glutarate-dehydrogenase-lipoyl
# o_GLYCEROL-3P
# o_CARBON-DIOXIDE
# o_GDP
# o_CARBAMOYL-P
# o_ssDNA-RNA-primer-hybrid
# o_HYDROXYMETHYLBILANE
# o_Holo-Hydroxymethylbilane-Synthase
# o_23S-rRNA-2-O-methylguanosine2251
# o_PROTEIN-LIPOYLLYSINE
# o_DIHYDROLIPOYL-GCVH
# o_PYRUVATE
# o_NADPH
# o_NADP
# o_CPD-19144
# o_3-CARBOXY-3-HYDROXY-ISOCAPROATE
# o_G3P
# o_2-PG
# o_MAL
# o_FUM
# o_2-Hexadecenoyl-ACPs
# o_ACP
# o_CANAVANINOSUCCINATE
# o_AMP
# o_Protein-Histidines
# o_23-DIPHOSPHOGLYCERATE
# o_Protein-pi-phospho-L-histidines
# o_CPD-16758
# o_CPD-653
# o_NADH-P-OR-NOP
# o_XANTHINE
# o_ETR-Quinols
# o_DIHYDROXY-ACETONE-PHOSPHATE
# o_OXALACETIC_ACID
# o_FRUCTOSE-6P
# o_CPD-15709
# o_ETF-Reduced
# o_DIHYDROFOLATE
# o_L-ARGININO-SUCCINATE
# o_Cysteine-Desulfurase-L-cysteine
# o_Acceptor
# o_Peptides-holder
# o_SUC
# o_5-10-METHENYL-THF-GLU-N
# o_CPD0-2108
# o_Pyruvate-dehydrogenase-dihydrolipoate
# o_ERYTHRONATE-4P
# o_THF-GLU-N
# o_AMINOMETHYLDIHYDROLIPOYL-GCVH
# o_METHYLENE-THF-GLU-N
# o_DIHYDRONEOPTERIN-P3
# o_FORMATE
# o_CPD0-2121
# o_RIBOSE-5P
# o_CPD0-1162
# o_Pyruvate-dehydrogenase-acetylDHlipoyl
# o_L-ALPHA-ALANINE
# o_CPD-8534
# o_2-ALPHA-HYDROXYETHYL-THPP
# o_GLY
# o_CPD-11444
# o_THIAMINE-PYROPHOSPHATE
# o_CPD-19170
# o_2-KETOGLUTARATE
# o_GLT
# o_Leader-Sequences
# o_Ubiquinols
# o_CPD-19172
# o_CIT
# o_THREO-DS-ISO-CITRATE
# o_CPD-19169
# o_CMP
# o_UDP-OHMYR-ACETYLGLUCOSAMINE
# o_CIS-ACONITATE
# o_3-P-HYDROXYPYRUVATE
# o_ATP
# o_R-3-Hydroxypalmitoyl-ACPs
# o_DI-H-OROTATE
# o_MET
# o_CPD0-1158
# o_ACETYL-GLU
# o_CPD-7221
# o_CPD-7222
# o_Single-Stranded-DNAs
# o_TRP
# o_S-3-HYDROXYBUTANOYL-COA
# o_OH-ACYL-ACP
# o_R-3-hydroxystearoyl-ACPs
# o_5-HYDROXY-CTP
# o_ACET
# o_biotin-L-lysine-in-BCCP-dimers
# o_L-PHOSPHATIDATE
# o_PHENYL-PYRUVATE
# o_DIACETYL
# o_5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE
# o_NAD-P-OR-NOP
# o_CPD-13357
# o_HCO3
# o_H2CO3
# o_CYS
# o_OXIDIZED-GLUTATHIONE
# o_R-3-hydroxymyristoyl-ACPs
# o_CPD-15818
# o_5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE
# o_ACETOACETYL-COA
# o_PROT-CYS
# o_SER
# o_CPD-19839
# o_2K-4CH3-PENTANOATE
# o_LEU
# o_Protein-S-Acetyl-Cysteines
# o_5-P-BETA-D-RIBOSYL-AMINE
# o_Octadec-2-enoyl-ACPs
# o_METHIONYL-PEPTIDE
# o_FORMYL-L-METHIONYL-PEPTIDE
# o_3-Hydroxy-octanoyl-ACPs
# o_GTP
# o_Oxidized-NrdH-Proteins
# o_DGDP
# o_L-Methionylaminoacyl-tRNAs
# o_Beta-hydroxydecanoyl-ACPs
# o_Ox-Thioredoxin
# o_DUDP
# o_Charged-ARG-tRNAs
# o_L-GLUTAMATE_GAMMA-SEMIALDEHYDE
# o_2-ACETO-LACTATE
# o_RNASE-III-PROCESSING-PRODUCT-MRNA
# o_DELTA3-ISOPENTENYL-PP
# o_UDP-OHMYR-GLUCOSAMINE
# o_HEXANOYL-COA
# o_PHOSPHORIBOSYL-FORMIMINO-AICAR-P
# o_CPD-22313
# o_16S-rRNA-N6-dimethyladenine1518-1519
# o_DIMETHYL-D-RIBITYL-LUMAZINE
# o_R-3-hydroxydodecanoyl-ACPs
# o_2-ACETO-2-HYDROXY-BUTYRATE
# o_PHOSPHORIBOSYL-AMP
# o_2-KETO-ISOVALERATE
# o_PRO
# o_Beta-3-hydroxybutyryl-ACPs
# o_ILE
# o_BCAA-dehydrogenase-DH-lipoyl
# o_Charged-PHE-tRNAs
# o_PHOSPHORIBULOSYL-FORMIMINO-AICAR-P
# o_DADP
# o_D-glucopyranose-6-phosphate
# o_CPD-8625
# o_CPD-8624
# o_D-ALA-D-ALA
# o_P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE
# o_R-3-hydroxyhexanoyl-ACPs
# o_DCDP
# o_Phosphoglucomutase
# o_Phosphorylated-phosphoglucomutase
# o_ALPHA-GLUCOSE-16-BISPHOSPHATE
# o_CPD0-1456
# o_Charged-THR-tRNAs
# o_LIPID-IV-A
# o_HISTIDINOL
# o_CPD0-2123
# o_Diacylglycerol-Prolipoproteins
# o_Lipoprotein-signal-peptide
# o_K-HEXANOYL-COA
# o_UDP-N-ACETYL-D-GLUCOSAMINE
# o_CPD-12304
# o_CPD-12303
# o_Protein-S-methyl-L-cysteine
# o_DNA-Guanines
# o_Octanoyl-ACPs
# o_TMP
# o_DIHYDROFOLATE-GLU-N
# o_AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP
# o_DUTP
# o_IMIDAZOLE-ACETOL-P
# o_L-HISTIDINOL-P
# o_CPD-11997
# o_Charged-MET-tRNAs
# o_THIAMINE-P
# o_Resolution-of-Recombinational-Junction
# o_CPD-19186
# o_Charged-ILE-tRNAs
# o_HYPOXANTHINE
# o_PHOSPHO-ENOL-PYRUVATE
# o_L-methionyl-tRNAfmet
# o_CPD-15244
# o_tRNAs-containing-epoxy-quenosine
# o_ADENINE
# o_C4
# o_OH-HEXANOYL-COA
# o_2-Octenoyl-ACPs
# o_HISTIDINAL
# o_C6
# o_ACYL-SN-GLYCEROL-3P
# o_tRNA-with-7-aminomethyl-7-deazaguanine
# o_GUANINE
# o_Trans-D2-decenoyl-ACPs
# o_GAP
# o_Charged-PRO-tRNAs
# o_Deoxy-Ribonucleoside-Diphosphates
# o_AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE
# o_CH33ADO
# o_AMINO-HYDROXYMETHYL-METHYL-PYR-P
# o_CPD0-2105
# o_3-oxo-decanoyl-ACPs
# o_Saturated-Fatty-Acyl-ACPs
# o_UDP-AA-GLUTAMATE
# o_CPD0-2107
# o_DIAMINO-OH-PHOSPHORIBOSYLAMINO-PYR
# o_D-GLUCOSAMINE-6-P
# o_GLUCOSAMINE-1P
# o_tRNA-Dihydrouridines
# o_CPD0-1096
# o_Phosphorylated-Phosphoglucosamine-Mutase
# o_Phosphoglucosamine-Mutase
# o_CPD-12258
# o_UMP
# o_a-mature-triacylated-lipoprotein
# o_1-Lyso-phospholipids
# o_C3
# o_CDPDIACYLGLYCEROL
# o_7-8-DIHYDROPTEROATE
# o_CPD0-2244
# o_CDP-2-3-4-Saturated-Diacylglycerols
# o_OXALO-SUCCINATE
# o_C5
# o_CPD-16013
# o_Nucleoside-Diphosphates
# o_CDP-1-Acyl-2-Arachidonoyl-Glycerols
# o_DEOXY-D-RIBOSE-1-PHOSPHATE
# o_DEOXYINOSINE
# o_PANTETHEINE-P
# o_C1
# o_Unsulfurated-Sulfur-Acceptors
# o_CMP-KDO
# o_Charged-ASP-tRNAs
# o_DUMP
# o_CPD-19840
# o_ACETALD
# o_TRANS-D2-ENOYL-ACP
# o_3-terminal-unsaturated-sugars
# o_CPD0-2106
# o_CPD-18238
# o_AICAR
# o_CARBAMATE
# o_tRNAs
# o_N-Substituted-Amino-Acids
# o_XYLULOSE-5-PHOSPHATE
# o_DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE
# o_PORPHOBILINOGEN
# o_tRNA-Containing-5AminoMe-2-ThioUrdines
# o_DPG
# o_Tetradec-2-enoyl-ACPs
# o_Charged-CYS-tRNAs
# o_CYS-tRNAs
# o_Hydroxymethylbilane-Synthase-ES2
# o_16S-rRNA-N2-methylguanine966
# o_Relaxed-DNAs
# o_Negatively-super-coiled-DNAs
# o_CPD-10267
# o_URIDINE
# o_L-3-HYDROXYACYL-COA
# o_TusA-Persulfides
# o_2-DEHYDROPANTOATE
# o_Charged-VAL-tRNAs
# o_N-ACETYL-D-GLUCOSAMINE-1-P
# o_CPD-19167
# o_4-P-PANTOTHENATE
# o_UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE
# o_5-PHOSPHORIBOSYL-N-FORMYLGLYCINEAMIDINE
# o_3-oxo-dodecanoyl-ACPs
# o_KDO
# o_PANTOTHENATE
# o_DNA-N
# o_MONOMER0-4342
# o_SN-GLYCEROL-1-PHOSPHATE
# o_TusE-S-sulfanylcysteine
# o_TusD-L-cysteine
# o_16S-rRNA-N7-methylguanine527
# o_FRUCTOSE-16-DIPHOSPHATE
# o_L-BETA-ASPARTYL-P
# o_tRNA-fragment
# o_Crotonyl-ACPs
# o_Saturated-Fatty-Acyl-CoA
# o_CPD0-2353
# o_DATP
# o_Charged-GLN-tRNAs
# o_PRPP
# o_carboxybiotin-L-lysine-in-BCCP-dimers
# o_mnm5GeS2U
# o_CPD-14443
# o_Charged-LEU-tRNAs
# o_Charged-GLT-tRNAs
# o_Charged-GLY-tRNAs
# o_LAUROYLCOA-CPD
# o_IMP
# o_D-ERYTHRO-IMIDAZOLE-GLYCEROL-P
# o_DGTP
# o_S-CD-Apo-SP-Complex
# o_NICOTINAMIDE_NUCLEOTIDE
# o_mnm5SeP2U
# o_CPD-22373
# o_DNA-Ligase-L-lysine-adenylate
# o_Charged-TYR-tRNAs
# o_CPD-10330
# o_CPD0-1108
# o_Menaquinols
# o_PROTOPORPHYRIN_IX
# o_DNA-Ligase-L-lysine
# o_A-5-prime-PP-5-prime-DNA
# o_N-formyl-L-methionyl-tRNAfmet
# o_FORMYL-THF-GLU-N
# o_CD-S-SP-Complex
# o_CPD0-181
# o_RNA-Holder
# o_CPD-11763
# o_CPD-11281
# o_CD-2S-SP-Complex
# o_3-oxo-palmitoyl-ACPs
# o_PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE
# o_DEAMIDO-NAD
# o_Mnm5Se2U-containing-tRNAs
# o_N-ALPHA-ACETYLORNITHINE
# o_Ribonucleoside-Diphosphates
# o_TusA-L-cysteine
# o_TusD-Persulfides
# o_CPD0-2354
# o_CD-SP-2Fe2S-Complex
# o_OROTIDINE-5-PHOSPHATE
# o_D-Ribopyranose
# o_BISOHMYR-GLUCOSAMINYL-1P
# o_INOSINE
# o_Co-chaperone-SP-2Fe2S-Complex
# o_L-Cysteine-Desulfurases
# o_GLUTAMATE-1-SEMIALDEHYDE
# o_GLT-tRNAs
# o_PALMITYL-COA
# o_CPD-12377
# o_OH
# o_FE+3
# o_tRNA-pseudouridine-38-40
# o_SHIKIMATE
# o_XANTHOSINE
# o_RIBOSE-1P
# o_CPD-19168
# o_Chap-ATP-Co-chaperone-SP-2Fe2S-Complex
# o_CPD-15435
# o_CPD-12366
# o_ARABINOSE-5P
# o_3-oxo-stearoyl-ACPs
# o_2Fe-2S-proteins
# o_FeS-Cluster-Co-Chaperones
# o_Chap-ADP-apo-SP-Complex
# o_CPD0-1163
# o_XANTHOSINE-5-PHOSPHATE
# o_Oxidized-2Fe-2S-Ferredoxins
# o_FeS-Cluster-Chaperones-ATP
# o_D-form-FeS-Cluster-Scaffold-Proteins
# o_INDOLE-3-GLYCEROL-P
# o_Release-factor-N5-Methyl-L-glutamine
# o_B-KETOACYL-ACP
# o_Charged-HIS-tRNAs
# o_3-oxo-hexanoyl-ACPs
# o_S-ADENOSYLMETHIONINE
# o_Reduced-2Fe-2S-Ferredoxins
# o_a-pyruvate-dehydrogenase-E2-protein-Nsup
# o_Pyruvate-dehydrogenase-lipoate
# o_DNA-Segment-Placeholder
# o_DNA-Segment-in-Reverse-Orientations
# o_CPD-18118
# o_CPD-18085
# o_CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P
# o_Charged-LYS-tRNAs
# o_a-2-oxoglutarate-dehydrogenase-E2-protei
# o_BISOHMYR-GLC
# o_TTP
# o_KDO-8P
# o_COPROPORPHYRINOGEN_III
# o_N-5-PHOSPHORIBOSYL-ANTHRANILATE
# o_Butanoyl-ACPs
# o_GUANOSINE-5DP-3DP
# o_DCTP
# o_CTP
# o_SHIKIMATE-5P
# o_Charged-ALA-tRNAs
# o_Hexanoyl-ACPs
# o_Dodec-2-enoyl-ACPs
# o_PHOSPHORIBOSYL-ATP
# o_CPD-22307
# o_DIHYDROPTERIN-CH2OH-PP
# o_tRNA-containing-5-CarbMeAminome-2-ThioU
# o_CPD-13851
# o_GDP-TP
# o_tRNA-containing-5-CarbMeAminome-uridine
# o_Palmitoyl-ACPs
# o_Decanoyl-ACPs
# o_3-oxo-myristoyl-ACPs
# o_ENOL-PHENYLPYRUVATE
# o_Charged-TRP-tRNAs
# o_CPD-7100
# o_CPD-196
# o_Dodecanoyl-ACPs
# o_DIHYDRO-NEO-PTERIN
# o_CPD-16954
# o_CPD-16953
# o_O-PHOSPHO-L-HOMOSERINE
# o_CPD0-2461
# o_Myristoyl-ACPs
# o_7-AMINOMETHYL-7-DEAZAGUANINE
# o_L-PANTOATE
# o_CPD-15436
# o_CPD-69
# o_CDP
# o_3OH-4P-OH-ALPHA-KETOBUTYRATE
# o_CPD0-2472
# o_BCCP-biotin-L-lysine
# o_3-Oxo-octanoyl-ACPs
# o_Hex-2-enoyl-ACPs
# o_BIO-5-AMP
# o_KDO-LIPID-IVA
# o_SS-Oligodeoxyribonucleotides
# o_Ribonucleoside-Monophosphates
# o_CPD-19753
# o_3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P
# o_UDP-N-ACETYLMURAMATE
# o_3-ENOLPYRUVYL-SHIKIMATE-5P
# o_CPD-14133
# o_L-seryl-SEC-tRNAs
# o_CPD-19171
# o_NICOTINATE_NUCLEOTIDE
# o_CPD0-2554
# o_Charged-SER-tRNAs
# o_L-ALPHA-AMINO-EPSILON-KETO-PIMELATE
# o_Charged-ASN-tRNAs
# o_GLYCOLALDEHYDE
# o_16S-rRNA-2-O-methylcytidine1402
# o_DIHYDROXY-BUTANONE-P
# o_ADENYLOSUCC
# o_RIBOFLAVIN
# o_OH-MYRISTOYL
# o_DEPHOSPHO-COA
# o_PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE
# o_CPD-602
# o_CO3
# o_5-PHOSPHO-RIBOSYL-GLYCINEAMIDE
# o_S-CD-S-SP-Complex
# o_CARBAMYUL-L-ASPARTATE
# o_16S-rRNA-N4-methylcytidine1402
# o_CPD0-2351
# o_DNA-Holder
# o_16S-rRNA-N3-methyluracil1498
# o_Hydroxymethylbilane-Synthase-ES
# o_L-Methionine-sulfoxides
# o_R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE
# o_N-ACETYL-GLUTAMYL-P
# o_Persulfurated-L-cysteine-desulfurases
# o_5-Phosphooxy-L-glutamyl-tRNAGlln
# o_L-glutamyl-tRNAGln
# o_4-Phosphooxy-L-aspartyl-tRNAAsn
# o_Methylated-methyl-acceptors
# o_LINOLENOYL-COA
# o_CPD-18351
# o_CPD-18350
# o_CPD-14928
# o_CPD-18352
# o_CPD-14269
# o_CPD-18346
# o_CPD-17371
# o_CPD-17373
# o_CPD-17372
# o_CPD-17641
# o_CPD-17640
# o_CPD0-1425
# o_18-HYDROXYOLEATE
# o_CPD-17370
# o_CPD-17273
# o_CPD0-2113
# o_R2-2OH-Straight-Chain-234-Sat-FA-CoA
# o_CPD-18390
# o_CPD-18
# o_1-Stearoyl-L-Phosphatidate
# o_CPD-17621
# o_CPD-18380
# o_3-Methyl-Saturated-Fatty-Acyl-CoA
# o_CPD-18353
# o_CPD0-1422
# o_CPD-14675
# o_2-Palmitoyl-L-Phosphatidate
# o_CPD0-1423
# o_Odd-Saturated-Fatty-Acyl-CoA
# o_CPD-8268
# o_2-Me-Branched-234-Sat-Fatty-Acyl-CoA
# o_CPD-17319
# o_1-Alkyl-2-acyl-glycerol-3-phosphate
# o_CPD-14018
# o_CPD-17638
# o_2-3-4-Saturated-L-Phosphatidates
# o_OCTADEC-9-ENE-118-DIOIC-ACID
# o_CPD-17624
# c_FORMYL-THF-GLU-N
# c_METHYLENE-THF-GLU-N
# c_N5-Formyl-THF-Glu-N
# c_THF-GLU-N
# c_DNA-N
# c_RNA-Holder
# c_ssRNAs
# c_CPD0-2350
#
# ######################################################################################################################################################
#
# 478
# i_NA+
# i_FERRIC-ENTEROBACTIN-COMPLEX
# i_CPD0-2482
# i_CPD-21612
# i_CPD-8938
# i_5-AMINOPENTANOATE
# i_3-BETA-D-GLUCOSYLGLUCOSE
# i_Apocytochromes-c
# i_CPD0-2039
# i_K+
# i_CPD-4544
# i_L-XYLULOSE
# i_CPD-13853
# i_CPD-14101
# i_C55-PP-GLCNAC-MANNACA-FUC4NAC
# i_CPD0-2705
# i_CPD-12797
# i_CPD-3561
# i_CPD-17205
# i_PTSH-PHOSPHORYLATED
# i_Aldoses
# i_a-DNA-3-deoxyribose-5-phosphate
# i_CPD-8989
# i_Drugs
# i_CPD-18902
# i_RNA-Ligase-L-histidine-guanylate
# i_1iNisup6sup-ethenoadenine-in-DNA
# i_LI+
# i_CPD0-889
# i_CPD-22329
# i_a-DNA-nucleotide-3-phosphoglycolaldehyde
# i_34-DIHYDROXYPHENYLPYRUVATE
# i_Red-thioredoxins-1
# i_an-oxidized-DsbD-protein
# i_CPD0-2511
# i_N7-METHYLGUANINE-IN-DNA
# i_CPD-24463
# i_DTDP-D-FUCOSE
# i_CPD-6602
# i_Inactive-Der-GTPAses
# i_3-Prime-Phosphate-Terminated-DNAs
# i_CPD-23428
# i_CPD-23427
# i_CPD-20894
# i_Exoaminopeptidase-Substrates
# i_3-Dehydro-D-Glucosides
# i_CPD-476
# i_YHAV-DEGRADATION-SUBSTRATE-MRNA
# i_CPD0-1938
# i_DNA-with-Holiday-Junctions
# i_a-DNA-nucleotide-3-phosphoglycolate
# i_CPD-20888
# i_CPD-24805
# i_CPD0-1171
# i_CPD0-1470
# i_phosphoethanolamine-cellulose
# i_DIACYLGLYCEROL-PYROPHOSPHATE
# i_CcmH-CcmG
# i_Reduced-CcmG-Proteins
# i_CytC-CcmH-Heme-CcmE
# i_A-5-prime-NAD-capped-RNA
# i_A-NM5-ICL
# i_RNA-with-3-prime-pp-5-prime-G-cap
# i_5Prime-OH-Terminated-RNAs
# i_CPD-13314
# i_D-GALACTURONATE
# i_CPD-7970
# i_Oxidized-CcmG-Proteins
# i_a-reduced-DsbD-protein
# i_Nucleoside-3-5-bisphosphate
# i_CPD-264
# i_CPD-22801
# i_HOMOCYSTINE
# i_CPD-24488
# i_D-ARABINOSE
# i_mRNAs-with-5-diphosphate
# i_Pre-crRNAs
# i_THIOGLYCOLATE
# i_3-CHLORO-D-ALANINE
# i_EF-P-lysyl-lysine
# i_CPD0-1564
# i_CPD-13851
# i_CPD0-1885
# i_3-Dehydro-D-gulosides
# i_CPD-18901
# i_BROMOACETATE
# i_CPD-24196
# i_11-DEOXYCORTICOSTERONE
# i_CPD-20940
# i_Oxidized-CcmH-Proteins
# i_CPD-17082
# i_a-uracil-in-DNA-I
# i_CPD-11648
# i_23S-rRNA-cytosine-2501
# i_PTSI-PHOSPHORYLATED
# i_DEOXYCHOLATE
# i_CPD-22331
# i_CytC-CcmH
# i_CcmE-Protein-Heme
# i_a-thymine-glycol-in-DNA
# i_CPD-660
# i_CPD-3582
# i_CU+
# i_Lipoyl-ACPs
# i_CPD0-2331
# i_PHENYLHYDANTOIN
# i_D-TARTRATE
# i_a-5-deoxyribose-5-phosphate-DNA
# i_CPD-21025
# i_CPD-2482
# i_MI-PENTAKISPHOSPHATE
# i_5-methoxycarbonylmethoxyU34-tRNA
# i_ETHYL-2-METHYLACETOACETATE
# i_Reduced-Disulfide-Carrier-Proteins
# i_CPD-18499
# i_CcmCDE-Complex
# i_Oxidized-Flavorubredoxins
# i_CPD-20890
# i_CPD0-2552
# i_L-Galactose
# i_Disulfide-Isomerase-with-Disulfide-Bond
# i_P-BENZOQUINONE
# i_CPD0-1083
# i_a-YedK-protein-L-cysteine
# i_a-single-stranded-DNA-with-ring-opened-a
# i_CPD0-1156
# i_Glutamates
# i_CPD-23288
# i_Lysophosphatidylglycerols
# i_Reduced-Flavorubredoxins
# i_CPD-8876
# i_Aliphatic-Omega-Amino-Aldehydes
# i_PROTEIN-S-HYDROXY-CYSTEINE
# i_CPD-24198
# i_signal-peptide
# i_Aminopeptidase-Substrates
# i_23S-rRNAs
# i_S-2-AMINOETHYL-L-CYSTEINE
# i_CPD-22802
# i_L-ARABINOSE
# i_CPD-21015
# i_CPD-7249
# i_CPD-7248
# i_D-gulosides
# i_CR+6
# i_CPD-3785
# i_CPD-23431
# i_CPD-18719
# i_CPD-18903
# i_CPD-18500
# i_A-2-METHYLTHIOCYTOSINE32-IN-TRNA
# i_RNA-Ligase-L-histidine
# i_CPD-24197
# i_CPD-3565
# i_Proteins-with-N-terminal-L-arginine
# i_N3-METHYLCYTOSINE-RNA
# i_50S-Ribosomal-subunit-protein-L16-Arg
# i_D-TYROSYL-TRNATYR
# i_CPD-1093
# i_CPD-24487
# i_CPD-10774
# i_METHYL-BETA-D-GALACTOSIDE
# i_L-LYXOSE
# i_GLUCURONATE
# i_CPD-18501
# i_an-alpha-deoxyadenosine-in-DNA
# i_CPD-17129
# i_CPD-12349
# i_CPD0-441
# i_CU+2
# i_N1-METHYLADENINE-RNA
# i_CPD0-2339
# i_CPD-511
# i_CPD0-2461
# i_CPD-21409
# i_CPD-20921
# i_CPD-17752
# o_NA+
# o_CPD-17082
# o_CPD-21612
# o_ACETOL
# o_CPD0-2482
# o_CPD-381
# o_CPD0-2039
# o_N5-Formyl-THF-Glu-N
# o_K+
# o_MELIBIOSE
# o_CPD-14101
# o_CPD-13853
# o_CPD0-2705
# o_CPD-19233
# o_DEOXYCHOLATE
# o_CPD-3561
# o_CPD-17206
# o_CPD-17205
# o_Alpha-lactose
# o_PTSH-MONOMER
# o_HEME_D
# o_Aldonic-Acids
# o_3-Hydroxy-Terminated-DNAs
# o_Drugs
# o_CPD-18903
# o_RNA-with-3-prime-pp-5-prime-G-cap
# o_RNA-Ligase-L-histidine
# o_CPD-8887
# o_LI+
# o_5-HYDROXYU34-TRNA
# o_CPD-3801
# o_CPD-17530
# o_CPD-16500
# o_CPD-24487
# o_CPD-19745
# o_CPD-6982
# o_Ox-thioredoxins-1
# o_a-reduced-DsbD-protein
# o_ADENOSINE5TRIPHOSPHO5ADENOSINE
# o_CPD-16720
# o_Protein-tauphospho-L-histidines
# o_CPD0-2377
# o_CPD0-2331
# o_CPD-22329
# o_DTDP-D-FUCOSE
# o_CPD-15407
# o_CPD-13314
# o_CPD-10797
# o_Der-GTPase
# o_CPD-23428
# o_CPD-23427
# o_CPD-20894
# o_Glucosides
# o_KYNURENATE
# o_a-5-deoxyribose-5-phosphate-DNA
# o_CPD0-2634
# o_CPD0-1938
# o_CPD-13243
# o_CPD-20888
# o_D-GALACTARATE
# o_A-PEPTIDOGLYCAN-MDAP-TRIPEPTIDE
# o_a-murein-lipoprotein
# o_CPD0-1470
# o_phosphoethanolamine-cellulose
# o_CELLULOSE
# o_Adenylated-Proteins
# o_Oxidized-CcmG-Proteins
# o_Reduced-CcmH-Proteins
# o_ETR-Semiquinones
# o_CcmH-CcmG
# o_CcmE-Proteins
# o_5-prime-phospho-adenosine-RNA
# o_CPD-23534
# o_A-DNA-WITH-OPPOSING-AP-SITE
# o_CPD-13315
# o_CPD0-1065
# o_D-GALACTURONATE
# o_CPD-7970
# o_Reduced-CcmG-Proteins
# o_an-oxidized-DsbD-protein
# o_CPD-4544
# o_CPD0-1110
# o_CPD-22802
# o_HOMOCYSTINE
# o_D-ARABINOSE
# o_crRNAs
# o_S-CARBOXYMETHYL-D-CYSTEINE
# o_EF-P-lysyl-hydroxylysine
# o_CPD0-1564
# o_CPD-13852
# o_2-MERCAPTOETHANOL
# o_N6-met-threonylcarbamoyl-A37-tRNAs
# o_3-Dehydro-D-gulosides
# o_3-Dehydro-D-Glucosides
# o_CPD-18902
# o_CPD0-2370
# o_Colanic-Acid-PP-Und
# o_CPD-16843
# o_CPD-20940
# o_CytC-CcmH
# o_CYSTINE
# o_a-DNA-3-alpha-beta-unsaturated-aldehyde
# o_5-Hydroxy-23S-rRNA-Cytosines2501
# o_PTSI-MONOMER
# o_3-HYDROXYPHENYL-PROPIONATE
# o_CPD-22332
# o_CytC-CcmH-Heme-CcmE
# o_CPD-18012
# o_CPD-660
# o_CPD-16619
# o_CU+2
# o_CPD0-2339
# o_Lysophosphatidylglycerols
# o_CPD-8524
# o_D-TARTRATE
# o_CPD-22978
# o_CPD-21025
# o_CPD0-2664
# o_CIS-DELTA3-ENOYL-COA
# o_CPD-2482
# o_CPD-18901
# o_CPD-1843
# o_CPD0-1151
# o_mcmo5U34m-tRNA
# o_ETHYL-2R-METHYL-3S-HYDROXYBUTANOATE
# o_Oxidized-Disulfide-Carrier-Proteins
# o_CPD-18499
# o_Donor-H1
# o_CcmCDE-Complex-Heme
# o_Reduced-Flavorubredoxins
# o_CPD-12587
# o_CPD-20890
# o_7-METHYLGUANOSINE-5-PHOSPHATE
# o_L-Galactose
# o_Reduced-Disulfide-Isomerases
# o_a-single-stranded-DNA-YedK-thiazolidine-
# o_CPD0-1157
# o_CPD-23289
# o_CPD-23288
# o_Oxidized-Flavorubredoxins
# o_CPD-7867
# o_CPD-476
# o_Aliphatic-Alpha-Omega-Diamines
# o_Aliphatic-Omega-Amino-Aldehydes
# o_PROTEIN-S-HYDROXY-CYSTEINE
# o_CPD-24197
# o_CPD-22331
# o_2-CARBOXYMUCONATE
# o_S-2-AMINOETHYL-L-CYSTEINE
# o_CPD-22805
# o_L-ARABINOSE
# o_CPD-21015
# o_CPD-7249
# o_CPD-7248
# o_CR+3
# o_MI-PENTAKISPHOSPHATE
# o_CPD-18719
# o_CPD-6746
# o_CPD-18500
# o_Apocytochromes-c-Disulfide
# o_tRNA-2methyladenine-37
# o_RNA-Ligase-L-histidine-guanylate
# o_CPD-24196
# o_CPD-3565
# o_RNA-Cytosines
# o_CPD-24463
# o_CPD-24126
# o_CPD0-1184
# o_50S-Ribo-protein-L16-Hydroxylarginine
# o_CPD-8539
# o_CPD-611
# o_CPD-24488
# o_METHYL-BETA-D-GALACTOSIDE
# o_S-METHYLGLUTATHIONE
# o_GLUCURONATE
# o_CPD3O-0
# o_CPD-24198
# o_CPD-16009
# o_CPD-18501
# o_a-5-alpha-deoxyadenosine-5-phosphate-DNA
# o_CPD-12349
# o_CPD-17129
# o_CPD0-441
# o_CU+
# o_RNA-Adenines
# o_CPD-3785
# o_CPD-24804
# o_CPD-497
# o_CPD-21406
# o_CPD-21407
# o_CPD-20921
# o_CPD-17753
# c_CPD0-2039
# c_GLT
# c_VAL
# c_Drugs
# c_FUM
# c_SUC
# c_CPD-10774
# c_D-galactopyranose
# c_FERRIC-ENTEROBACTIN-COMPLEX
# c_Glycerophosphodiesters
# c_MAL
# c_CPD0-2486
# c_CPD0-2485
# c_CPD-3561
# c_Alpha-lactose
# c_CPD-20940
# c_Unspecified-Ion-Or-Solute
# c_LOS
# c_LI+
# c_METHYL-BETA-D-GALACTOSIDE
# c_D-LACTATE
# c_CPD-3801
# c_Apocytochromes-c
# c_CPD-22805
# c_CPD0-621
# c_CPD-10797
# c_Polymyxins
# c_CPD-20894
# c_CPD0-1938
# c_CPD-20888
# c_D-GALACTARATE
# c_Gentamycins
# c_CPD0-1470
# c_INDOLE
# c_CHOLATE
# c_CPD-15554
# c_5-AMINOPENTANOATE
# c_OROTATE
# c_D-GALACTURONATE
# c_CPD-7970
# c_SELENITE
# c_ILE
# c_CPD-21025
# c_CPD-4544
# c_CPD-8876
# c_D-ARABINOSE
# c_DEOXYCHOLATE
# c_CPD-15417
# c_SULFO-CYSTEINE
# c_Macrolide-Antibiotics
# c_EG11489-MONOMER
# c_CPD-9288
# c_CANAVANINE
# c_CPD-21070
# c_CPD0-2482
# c_URATE
# c_CPD-660
# c_CPD0-1080
# c_CPD0-1081
# c_CPD-24196
# c_CPD0-882
# c_CPD0-1123
# c_Erythromycins
# c_AG+
# c_a-lyso-cardiolipin
# c_CPD-2482
# c_GUANOSINE
# c_B-ALANINE
# c_CPD-14545
# c_CPD-18499
# c_CPD-20890
# c_L-ALA-GAMMA-D-GLU-DAP
# c_L-Galactose
# c_CPD0-1083
# c_Lysophosphatidylglycerols
# c_GLYCOLLATE
# c_2-ACYL-GPE
# c_S-2-AMINOETHYL-L-CYSTEINE
# c_D-glucopyranose-6-phosphate
# c_DEOXYURIDINE
# c_CPD-21015
# c_INOSINE
# c_L-GLYCERALDEHYDE-3-PHOSPHATE
# c_CPD-3738
# c_CPD-18719
# c_D-TARTRATE
# c_CPD-21777
# c_CPD-18500
# c_CPD-15979
# c_CPD-3565
# c_CPD-3617
# c_CPD-15189
# c_GLYCERATE
# c_CPD-24126
# c_L-Methionine-sulfoxides
# c_Long-Chain-Fatty-Acids
# c_CPD-18254
# c_GLUCURONATE
# c_CPD-18501
# c_D-GLUCARATE
# c_HYPOXANTHINE
# c_CPD-3564
# c_CPD0-441
# c_ADENINE
# c_CPD-3785
# c_TARTRATE
# c_CPD-497
# c_CPD-20921
# c_THYMINE
#
# ######################################################################################################################################################
#
# 114
# i_CPD-14550
# i_CPD-12029
# i_Polyketide-synthase-PKS13
# i_CPD1G-332
# i_CPD1G-408
# i_CPD-12063
# i_Mycobacterial-Arabinogalactans
# i_CPD1G-1345
# i_CPD1G-106
# i_cis-19-CP-37-Mex-38-Me-C59-ACPs
# i_CPD1G-1346
# i_CPD1G-69
# i_C78-alpha-mycolate-pks13
# i_cis-D19-37-OH-38-Me-C57-1-ACPs
# i_CPD1G-107
# i_CPD1G-252
# i_CPD1G-1353
# i_trans-18-CP-37-Mex-38-Me-C60-ACPs
# i_CPD1G-108
# i_CPD1G-1354
# i_C85-cis-methoxy-mycolate-pks13
# i_trans-D18-37-MOH-38-Me-C58-1-ACPs
# i_CPD1G-360
# i_cis-21-CP-39-keto-40-Me-C60-ACPs
# i_cis-D21-39-OH-40-Me-C59-1-ACPs
# i_C86-trans-methoxy-mycolate-pks13
# i_3-oxo-C78-alpha-mycolate-pks13
# i_trans-D20-39-OH-40-Me-C60-1-ACPs
# i_CPD-2209
# i_trans-20-CP-22-Me-39-keto-40-Me-C61-ACPs
# i_C86-cis-keto-mycolate-pks13
# i_3-oxo-C85-cis-methoxy-mycolate-pks13
# i_trans-D18-37-OH-38-Me-C58-1-ACPs
# i_CPD-12040
# i_CPD-12028
# i_CPD1G-1344
# i_C87-trans-keto-mycolate-pks13
# i_CPD-12030
# i_CPD-12054
# i_3-oxo-C86-trans-methoxy-mycolate-pks13
# i_CPD1G-124
# i_CPD-12060
# i_CPD1G-83
# i_trans-D20-39-oxo-40-Me-C60-1-ACPs
# i_3-oxo-C86-cis-keto-mycolate-pks13
# i_CPD1G-204
# i_CPD1G-105
# i_cis-cis-19-31-dicyclopropyl-C52-ACPs
# i_CPD-12051
# i_3-oxo-C87-trans-keto-mycolate-pks13
# o_CPD-12030
# o_3-oxo-C87-trans-keto-mycolate-pks13
# o_CPD-12063
# o_CPD-12061
# o_CPD1G-1532
# o_CPD1G-69
# o_CPD1G-772
# o_CPD1G-204
# o_CPD1G-1533
# o_Polyketide-synthase-PKS13
# o_CPD1G-83
# o_trans-D18-37-OH-38-Me-C58-1-ACPs
# o_CPD1G-773
# o_3-oxo-C86-trans-methoxy-mycolate-pks13
# o_CPD1G-1534
# o_CPD1G-252
# o_CPD1G-774
# o_CPD-12040
# o_CPD1G-1535
# o_CPD1G-105
# o_trans-18-CP-37-Mex-38-Me-C60-ACPs
# o_CPD1G-277
# o_3-oxo-C86-cis-keto-mycolate-pks13
# o_CPD1G-360
# o_cis-D21-39-oxo-40-Me-C59-1-ACPs
# o_CPD1G-106
# o_cis-D21-39-OH-40-Me-C59-1-ACPs
# o_C78-alpha-mycolate-pks13
# o_trans-D20-39-oxo-40-Me-C60-1-ACPs
# o_CPD-12028
# o_CPD1G-408
# o_cis-D19-37-MOH-38-Me-C57-1-ACPs
# o_CPD1G-107
# o_CPD-2209
# o_C85-cis-methoxy-mycolate-pks13
# o_trans-D18-37-MOH-38-Me-C58-1-ACPs
# o_CPD-12029
# o_ALPHAALPHA-TREHALOSE-66-BISMYCOLATE
# o_cis-D19-37-OH-38-Me-C57-1-ACPs
# o_CPD1G-108
# o_CPD-12050
# o_trans-D20-39-OH-40-Me-C60-1-ACPs
# o_CPD-12051
# o_CPD1G-852
# o_C86-trans-methoxy-mycolate-pks13
# o_3-oxo-C78-alpha-mycolate-pks13
# o_CPD1G-853
# o_CPD-12054
# o_CPD1G-768
# o_trans-20-CP-22-Me-39-keto-40-Me-C61-ACPs
# o_CPD1G-854
# o_C86-cis-keto-mycolate-pks13
# o_cis-cis-19-31-dicyclopropyl-C52-ACPs
# o_3-oxo-C85-cis-methoxy-mycolate-pks13
# o_CPD1G-855
# o_CPD1G-771
# o_CPD1G-124
# o_CPD1G-1531
# o_C87-trans-keto-mycolate-pks13
# c_CPD1G-1344
# c_CPD1G-1345
# c_CPD1G-1346
# c_CPD1G-1353
# c_CPD1G-1354
#
# ######################################################################################################################################################
#
# 66
# i_3R-Hydroxyacyl-TYPE-I-FAS-ACPs
# i_Dodecanoyl-TYPE-I-FAS-ACPs
# i_Tetradec-2-enoyl-TYPE-I-FAS-ACPs
# i_3-oxo-myristoyl-TYPE-I-FAS-ACPs
# i_Crotonyl-TYPE-I-FAS-ACPs
# i_R-3-Hydroxypalmitoyl-TYPE-I-FAS-ACPs
# i_3-Oxo-Acyl-TYPE-I-FAS-ACPs
# i_3-Oxo-octanoyl-TYPE-I-FAS-ACPs
# i_Acetoacetyl-TYPE-I-FAS-ACP
# i_Dodec-2-enoyl-TYPE-I-FAS-ACPs
# i_3-oxo-decanoyl-TYPE-I-FAS-ACPs
# i_Myristoyl-TYPE-I-FAS-ACPs
# i_3-oxo-dodecanoyl-TYPE-I-FAS-ACPs
# i_3-oxo-hexanoyl-TYPE-I-FAS-ACPs
# i_R-3-hydroxyhexanoyl-TYPE-I-FAS-ACPs
# i_Trans-23-Dehydroacyl-TYPE-I-FAS-ACPs
# i_Octanoyl-TYPE-I-FAS-ACPs
# i_3-oxo-palmitoyl-TYPE-I-FAS-ACPs
# i_Hexanoyl-TYPE-I-FAS-ACPs
# i_Butanoyl-TYPE-I-FAS-ACPs
# i_2-Hexadecenoyl-TYPE-I-FAS-ACPs
# i_2-Octenoyl-TYPE-I-FAS-ACPs
# i_Beta-3-hydroxybutyryl-TYPE-I-FAS-ACPs
# i_Hex-2-enoyl-TYPE-I-FAS-ACPs
# i_Acetyl-TYPE-I-FAS-ACP
# i_Trans-D2-decenoyl-TYPE-I-FAS-ACPs
# i_Beta-hydroxydecanoyl-TYPE-I-FAS-ACPs
# i_R-3-hydroxydodecanoyl-TYPE-I-FAS-ACPs
# i_R-3-hydroxymyristoyl-TYPE-I-FAS-ACPs
# i_Holo-Fatty-Acid-Synthase-ACPs
# i_Decanoyl-TYPE-I-FAS-ACPs
# i_Acyl-TYPE-I-FAS-ACPs
# i_3-Hydroxy-octanoyl-TYPE-I-FAS-ACPs
# o_Trans-23-Dehydroacyl-TYPE-I-FAS-ACPs
# o_3-oxo-myristoyl-TYPE-I-FAS-ACPs
# o_Myristoyl-TYPE-I-FAS-ACPs
# o_R-3-hydroxymyristoyl-TYPE-I-FAS-ACPs
# o_Butanoyl-TYPE-I-FAS-ACPs
# o_2-Hexadecenoyl-TYPE-I-FAS-ACPs
# o_3R-Hydroxyacyl-TYPE-I-FAS-ACPs
# o_3-Hydroxy-octanoyl-TYPE-I-FAS-ACPs
# o_Beta-3-hydroxybutyryl-TYPE-I-FAS-ACPs
# o_Dodecanoyl-TYPE-I-FAS-ACPs
# o_Beta-hydroxydecanoyl-TYPE-I-FAS-ACPs
# o_3-oxo-palmitoyl-TYPE-I-FAS-ACPs
# o_R-3-hydroxydodecanoyl-TYPE-I-FAS-ACPs
# o_R-3-hydroxyhexanoyl-TYPE-I-FAS-ACPs
# o_Hex-2-enoyl-TYPE-I-FAS-ACPs
# o_Acyl-TYPE-I-FAS-ACPs
# o_3-oxo-decanoyl-TYPE-I-FAS-ACPs
# o_R-3-Hydroxypalmitoyl-TYPE-I-FAS-ACPs
# o_3-Oxo-octanoyl-TYPE-I-FAS-ACPs
# o_3-oxo-hexanoyl-TYPE-I-FAS-ACPs
# o_Palmitoyl-TYPE-I-FAS-ACPs
# o_Octanoyl-TYPE-I-FAS-ACPs
# o_Crotonyl-TYPE-I-FAS-ACPs
# o_Hexanoyl-TYPE-I-FAS-ACPs
# o_Acetoacetyl-TYPE-I-FAS-ACP
# o_Decanoyl-TYPE-I-FAS-ACPs
# o_Trans-D2-decenoyl-TYPE-I-FAS-ACPs
# o_Dodec-2-enoyl-TYPE-I-FAS-ACPs
# o_Tetradec-2-enoyl-TYPE-I-FAS-ACPs
# o_Acetyl-TYPE-I-FAS-ACP
# o_3-oxo-dodecanoyl-TYPE-I-FAS-ACPs
# o_3-Oxo-Acyl-TYPE-I-FAS-ACPs
# o_2-Octenoyl-TYPE-I-FAS-ACPs
#
# ######################################################################################################################################################
#
# 61
# i_cis-cis-D17-29-C48-2-ACPs
# i_cis-delta7-cerotoyl-ACPs
# i_cis-cis-D3-21-C40-2-ACPs
# i_cis-delta9-montanoyl-ACPs
# i_cis-cis-D5-23-C42-2-ACPs
# i_cis-delta11-melissoyl-ACPs
# i_cis-cis-D7-25-C44-2-ACPs
# i_cis-delta13-lacceroyl-ACPs
# i_cis-cis-D9-27-C46-2-ACPs
# i_cis-delta15-gheddoyl-ACPs
# i_cis-cis-D11-29-C48-2-ACPs
# i_cis-delta17-C36-ACPs
# i_cis-cis-D13-31-C50-2-ACPs
# i_cis-delta19-C38-ACPs
# i_cis-cis-D15-33-C52-2-ACPs
# i_cis-cis-D3-15-C34-2-ACPs
# i_cis-cis-D17-35-C54-2-ACPs
# i_cis-cis-D5-17-C36-2-ACPs
# i_cis-cis-D19-37-C56-2-ACPs
# i_cis-cis-D7-19-C38-2-ACPs
# i_cis-cis-D9-21-C40-2-ACPs
# i_cis-cis-D11-23-C42-2-ACPs
# i_cis-cis-D13-25-C44-2-ACPs
# i_cis-delta3-behenoyl-ACPs
# i_cis-cis-D15-27-C46-2-ACPs
# i_cis-delta5-lignoceroyl-ACPs
# o_cis-cis-D17-29-C48-2-ACPs
# o_cis-delta7-cerotoyl-ACPs
# o_cis-delta9-3-oxo-montanoyl-ACPs
# o_cis-cis-D3-21-C40-2-ACPs
# o_cis-delta11-3-oxo-melissoyl-ACPs
# o_cis-delta9-montanoyl-ACPs
# o_cis-cis-D5-23-C42-2-ACPs
# o_cis-delta13-3-oxo-lacceroyl-ACPs
# o_cis-delta11-melissoyl-ACPs
# o_cis-cis-D7-25-C44-2-ACPs
# o_cis-delta13-lacceroyl-ACPs
# o_cis-delta15-3-oxo-gheddoyl-ACPs
# o_cis-cis-D9-27-C46-2-ACPs
# o_cis-delta15-gheddoyl-ACPs
# o_cis-delta17-3-oxo-C36-ACPs
# o_cis-cis-D11-29-C48-2-ACPs
# o_cis-delta19-3-oxo-C38-ACPs
# o_cis-delta17-C36-ACPs
# o_cis-cis-D13-31-C50-2-ACPs
# o_cis-delta19-C38-ACPs
# o_cis-delta21-3-oxo-C40-ACPs
# o_cis-cis-D15-33-C52-2-ACPs
# o_cis-cis-D3-15-C34-2-ACPs
# o_cis-cis-D17-35-C54-2-ACPs
# o_cis-cis-D5-17-C36-2-ACPs
# o_cis-cis-D19-37-C56-2-ACPs
# o_cis-cis-D7-19-C38-2-ACPs
# o_cis-cis-D9-21-C40-2-ACPs
# o_cis-cis-D11-23-C42-2-ACPs
# o_cis-cis-D13-25-C44-2-ACPs
# o_cis-delta5-3-oxo-lignoceroyl-ACPs
# o_cis-delta3-behenoyl-ACPs
# o_cis-cis-D15-27-C46-2-ACPs
# o_cis-delta7-3-oxo-cerotoyl-ACPs
# o_cis-delta5-lignoceroyl-ACPs
#
# ######################################################################################################################################################
#
# 52
# i_trans-D2-cis-cis-D11-23-C42-3-ACPs
# i_trans-D2-cis-D9-montanoyl-ACPs
# i_trans-D2-cis-cis-D15-33-C52-3-ACPs
# i_trans-D2-cis-cis-D19-31-C50-3-ACPs
# i_trans-D2-cis-cis-D19-37-C56-3-ACPs
# i_trans-D2-cis-cis-D7-25-C44-3-ACPs
# i_trans-D2-cis-D19-C38-ACPs
# i_trans-D2-cis-cis-D11-29-C48-3-ACPs
# i_trans-D2-cis-cis-D5-17-C36-3-ACPs
# i_cis-cis-D21-39-C58-2-ACPs
# i_trans-D2-cis-cis-D9-21-C40-3-ACPs
# i_trans-D2-cis-D13-lacceroyl-ACPs
# i_trans-D2-cis-cis-D13-25-C44-3-ACPs
# i_trans-D2-cis-cis-D15-27-C46-3-ACPs
# i_trans-D2-cis-cis-D13-31-C50-3-ACPs
# i_trans-D2-cis-cis-D17-29-C48-3-ACPs
# i_trans-D2-cis-cis-D17-35-C54-3-ACPs
# i_trans-D2-cis-cis-D5-23-C42-3-ACPs
# i_trans-D2-cis-cis-D21-39-C58-3-ACPs
# i_trans-D2-cis-D17-C36-ACPs
# i_trans-D2-cis-cis-D9-27-C46-3-ACPs
# i_cis-cis-D19-31-C50-2-ACPs
# i_trans-D2-cis-cis-D7-19-C38-3-ACPs
# i_trans-D2-cis-D7-cerotoyl-ACPs
# i_trans-D2-cis-D11-melissoyl-ACPs
# i_trans-D2-cis-D5-lignoceroyl-ACPs
# o_trans-D2-cis-cis-D15-27-C46-3-ACPs
# o_trans-D2-cis-cis-D19-31-C50-3-ACPs
# o_trans-D2-cis-cis-D19-37-C56-3-ACPs
# o_trans-D2-cis-cis-D7-25-C44-3-ACPs
# o_cis-cis-D19-31-C50-2-ACPs
# o_trans-D2-cis-D19-C38-ACPs
# o_trans-D2-cis-cis-D17-29-C48-3-ACPs
# o_trans-D2-cis-cis-D11-29-C48-3-ACPs
# o_trans-D2-cis-cis-D5-17-C36-3-ACPs
# o_trans-D2-cis-cis-D13-31-C50-3-ACPs
# o_trans-D2-cis-cis-D9-21-C40-3-ACPs
# o_trans-D2-cis-cis-D13-25-C44-3-ACPs
# o_trans-D2-cis-D13-lacceroyl-ACPs
# o_trans-D2-cis-cis-D17-35-C54-3-ACPs
# o_trans-D2-cis-cis-D5-23-C42-3-ACPs
# o_trans-D2-cis-cis-D21-39-C58-3-ACPs
# o_trans-D2-cis-D17-C36-ACPs
# o_trans-D2-cis-cis-D9-27-C46-3-ACPs
# o_trans-D2-cis-D7-cerotoyl-ACPs
# o_cis-cis-D21-39-C58-2-ACPs
# o_trans-D2-cis-D9-montanoyl-ACPs
# o_trans-D2-cis-cis-D7-19-C38-3-ACPs
# o_trans-D2-cis-D11-melissoyl-ACPs
# o_trans-D2-cis-D5-lignoceroyl-ACPs
# o_trans-D2-cis-cis-D11-23-C42-3-ACPs
# o_trans-D2-cis-cis-D15-33-C52-3-ACPs
#
# ######################################################################################################################################################
#
# 52
# i_S-Alkyl-L-Cysteines
# i_Alkyl-Thiols
# i_CPD-9300
# i_CPD-21119
# i_CPD-7546
# i_CPD-21179
# i_CPD-21126
# i_CPD-21108
# i_CPD-21122
# i_CPD-21121
# i_CPDQT-407
# i_CPD-13717
# i_CPD-21169
# i_CPDQT-409
# i_S-Substituted-L-Cysteines
# i_Thiols
# i_CPDQT-410
# i_CPD-3740
# i_CPDQT-406
# i_CPD-21113
# i_CPD-7547
# i_CPD-21118
# i_CPD-21120
# i_CPD-7545
# i_CPDQT-408
# o_2-AMINOACRYLATE
# o_S-Substituted-L-Cysteines
# o_SELENOHOMOCYSTEINE
# o_S-Alkyl-L-Cysteines
# o_Alkyl-Thiols
# o_CPD-10467
# o_CPD-21110
# o_3-METHYLTHIOPROPYLHYDROXAMIC-ACID
# o_CPD-20053
# o_CPD-21128
# o_CPD-21078
# o_CPD-21116
# o_CPD-21115
# o_CPDQT-412
# o_CPD-13717
# o_CPD-21178
# o_CPDQT-414
# o_Thiols
# o_CPDQT-415
# o_CPD-19493
# o_CPDQT-411
# o_CPD-21114
# o_CPD-1861
# o_CPD-21109
# o_CPD-21111
# o_PHENYLACETOTHIOHYDROXIMATE
# o_CPDQT-413
#
# ######################################################################################################################################################
#
# 50
# i_4-Methyl-3-Hydroxypentanoyl-ACP
# i_3-Hydroxy-10-Methylundecanoyl-ACPs
# i_12-methyltridecanoyl-ACPs
# i_4-Methylpent-2-enoyl-ACP
# i_10-Methyl-Undec-2-enoyl-ACPs
# i_4-Methylpentanoyl-ACP
# i_10-Methylundecanoyl-ACPs
# i_6-Methyl-3-Oxoheptanoyl-ACP
# i_12-Methyl-3-Oxotridecanoyl-ACPs
# i_3-Hydroxy-6-Methylheptanoyl-ACPs
# i_3-Hydroxy-12-Methyltridecanoyl-ACPs
# i_6-Methyl-Hept-2-enoyl-ACPs
# i_12-Methyltridec-2-enoyl-ACPs
# i_6-Methylheptanoyl-ACPs
# i_8-Methyl-3-Oxononanoyl-ACPs
# i_14-Methyl-3-Oxopentadecanoyl-ACPs
# i_3-Hydroxy-8-Methylnonanoyl-ACPs
# i_3-Hydroxy-14-Methylpentadecanoyl-ACPs
# i_8-Methyl-Non-2-enoyl-ACPs
# i_14-Methyl-Pentadec-2-enoyl-ACPs
# i_8-Methylnonanoyl-ACPs
# i_4-Methyl-3-Oxopentanoyl-ACP
# i_14-Methylpentadecanoyl-ACPs
# i_10-Methyl-3-Oxoundecanoyl-ACPs
# o_4-Methylpent-2-enoyl-ACP
# o_10-Methyl-Undec-2-enoyl-ACPs
# o_CPD-19660
# o_4-Methylpentanoyl-ACP
# o_10-Methylundecanoyl-ACPs
# o_6-Methyl-3-Oxoheptanoyl-ACP
# o_12-Methyl-3-Oxotridecanoyl-ACPs
# o_3-Hydroxy-6-Methylheptanoyl-ACPs
# o_3-Hydroxy-12-Methyltridecanoyl-ACPs
# o_6-Methyl-Hept-2-enoyl-ACPs
# o_12-Methyltridec-2-enoyl-ACPs
# o_6-Methylheptanoyl-ACPs
# o_12-methyltridecanoyl-ACPs
# o_8-Methyl-3-Oxononanoyl-ACPs
# o_14-Methyl-3-Oxopentadecanoyl-ACPs
# o_3-Hydroxy-8-Methylnonanoyl-ACPs
# o_3-Hydroxy-14-Methylpentadecanoyl-ACPs
# o_8-Methyl-Non-2-enoyl-ACPs
# o_14-Methyl-Pentadec-2-enoyl-ACPs
# o_8-Methylnonanoyl-ACPs
# o_14-Methylpentadecanoyl-ACPs
# o_4-Methyl-3-Oxopentanoyl-ACP
# o_10-Methyl-3-Oxoundecanoyl-ACPs
# o_4-Methyl-3-Hydroxypentanoyl-ACP
# o_CPD-23515
# o_3-Hydroxy-10-Methylundecanoyl-ACPs
#
# ######################################################################################################################################################
#
# 50
# i_4-Methyl-3-Hydroxyhexanoyl-ACP
# i_8-Methyl-3-Oxo-Decanoyl-ACPs
# i_6-Methyl-Oct-2-enoyl-ACPs
# i_12-Methyl-3-Oxotetradecanoyl-ACPs
# i_4-Methylhexenoyl-ACP
# i_3-Hydroxy-12-Methyltetradecanoyl-ACPs
# i_8-Methyl-Dec-2-enoyl-ACPs
# i_10-Methyl-Dodec-2-enoyl-ACPs
# i_14-Methyl-Hexadec-2-enoyl-ACPs
# i_10-Methyldodecanoyl-ACPs
# i_14-Methylhexadecanoyl-ACPs
# i_4-Methylhexanoyl-ACP
# i_12-Methyltetradec-2-enoyl-ACPs
# i_12-methyltetradecanoyl-ACPs
# i_3-Hydroxy-6-Methyloctanoyl-ACPs
# i_6-Methyl-3-Oxooctanoyl-ACP
# i_3-Hydroxy-14-Methylhexadecanoyl-ACPs
# i_8-Methyldecanoyl-ACPs
# i_3-Hydroxy-8-Methyldecanoyl-ACPs
# i_14-Methyl-3-Oxohexadecanoyl-ACPs
# i_3-Hydroxy-10-Methyldodecanoyl-ACPs
# i_10-Methyl-3-Oxododecanoyl-ACPs
# i_6-Methyloctanoyl-ACPs
# i_4-Methyl-3-Oxohexanoyl-ACP
# o_4-Methylhexenoyl-ACP
# o_3-Hydroxy-8-Methyldecanoyl-ACPs
# o_6-Methyloctanoyl-ACPs
# o_3-Hydroxy-12-Methyltetradecanoyl-ACPs
# o_4-Methylhexanoyl-ACP
# o_12-Methyltetradec-2-enoyl-ACPs
# o_8-Methyldecanoyl-ACPs
# o_10-Methyldodecanoyl-ACPs
# o_14-Methylhexadecanoyl-ACPs
# o_12-Methyl-3-Oxotetradecanoyl-ACPs
# o_CPD-23509
# o_6-Methyl-3-Oxooctanoyl-ACP
# o_12-methyltetradecanoyl-ACPs
# o_14-Methyl-3-Oxohexadecanoyl-ACPs
# o_6-Methyl-Oct-2-enoyl-ACPs
# o_3-Hydroxy-6-Methyloctanoyl-ACPs
# o_14-Methyl-Hexadec-2-enoyl-ACPs
# o_10-Methyl-3-Oxododecanoyl-ACPs
# o_8-Methyl-Dec-2-enoyl-ACPs
# o_CPD-9917
# o_3-Hydroxy-14-Methylhexadecanoyl-ACPs
# o_10-Methyl-Dodec-2-enoyl-ACPs
# o_3-Hydroxy-10-Methyldodecanoyl-ACPs
# o_8-Methyl-3-Oxo-Decanoyl-ACPs
# o_4-Methyl-3-Oxohexanoyl-ACP
# o_4-Methyl-3-Hydroxyhexanoyl-ACP
#
# ######################################################################################################################################################
#
# 50
# i_3-Hydroxy-9-Methyldecanoyl-ACPs
# i_13-Methyltetradec-2-enoyl-ACPs
# i_5-Methylhexenoyl-ACP
# i_3-Hydroxy-13-Methyltetradecanoyl-ACPs
# i_11-Methyldodecanoyl-ACPs
# i_7-Methyloctanoyl-ACPs
# i_9-Methyl-Dec-2-enoyl-ACPs
# i_3-Hydroxy-15-Methylhexadecanoyl-ACPs
# i_5-Methylhexanoyl-ACP
# i_3-Hydroxy-7-Methyloctanoyl-ACPs
# i_11-Methyl-Dodec-2-enoyl-ACPs
# i_13-methyltetradecanoyl-ACPs
# i_15-Methyl-Hexadec-2-enoyl-ACPs
# i_5-Methyl-3-Oxohexanoyl-ACP
# i_7-Methyl-3-Oxooctanoyl-ACP
# i_7-Methyl-Oct-2-enoyl-ACPs
# i_9-Methyl-3-Oxo-Decanoyl-ACPs
# i_5-Methyl-3-Hydroxyhexanoyl-ACP
# i_11-Methyl-3-Oxododecanoyl-ACPs
# i_3-Hydroxy-11-Methyldodecanoyl-ACPs
# i_13-Methyl-3-Oxotetradecanoyl-ACPs
# i_15-Methyl-3-Oxohexadecanoyl-ACPs
# i_15-Methylhexadecanoyl-ACPs
# i_9-Methyldecanoyl-ACPs
# o_9-Methyl-Dec-2-enoyl-ACPs
# o_13-methyltetradecanoyl-ACPs
# o_5-Methylhexanoyl-ACP
# o_13-Methyltetradec-2-enoyl-ACPs
# o_13-Methyl-3-Oxotetradecanoyl-ACPs
# o_9-Methyl-3-Oxo-Decanoyl-ACPs
# o_9-Methyldecanoyl-ACPs
# o_15-Methyl-Hexadec-2-enoyl-ACPs
# o_7-Methyl-3-Oxooctanoyl-ACP
# o_7-Methyl-Oct-2-enoyl-ACPs
# o_11-Methyldodecanoyl-ACPs
# o_15-Methyl-3-Oxohexadecanoyl-ACPs
# o_15-Methylhexadecanoyl-ACPs
# o_5-Methyl-3-Oxohexanoyl-ACP
# o_5-Methyl-3-Hydroxyhexanoyl-ACP
# o_3-Hydroxy-7-Methyloctanoyl-ACPs
# o_7-Methyloctanoyl-ACPs
# o_3-Hydroxy-9-Methyldecanoyl-ACPs
# o_5-Methylhexenoyl-ACP
# o_3-Hydroxy-11-Methyldodecanoyl-ACPs
# o_11-Methyl-Dodec-2-enoyl-ACPs
# o_3-Hydroxy-13-Methyltetradecanoyl-ACPs
# o_3-Hydroxy-15-Methylhexadecanoyl-ACPs
# o_CPD-18175
# o_CPD-19657
# o_11-Methyl-3-Oxododecanoyl-ACPs
#
# ######################################################################################################################################################
#
# 39
# i_CPD-21411
# i_CPD-13680
# i_CPD-13754
# i_CPD-13755
# i_CPD-21416
# i_CPD-13756
# i_CPD-21417
# i_CPD-13712
# i_CPD-21412
# i_CPD-13708
# i_CPD-21418
# i_ANDROST4ENE
# i_CPD-13704
# i_CPD-21413
# i_CPD-13709
# i_CPD-21420
# i_CPD-13757
# i_Cis-2-enoyl-CoAs
# i_CPD-21414
# i_3-HYDROXY-5917-TRIOXO-45910-DISECOA
# o_CPD-13754
# o_CPD-21412
# o_CPD-13708
# o_CPD-13755
# o_CPD-21417
# o_CPD-13757
# o_CPD-21418
# o_CPD-21413
# o_CPD-13709
# o_CPD-21419
# o_CPD-13704
# o_CPD-13680
# o_CPD-21414
# o_3-HYDROXY-5917-TRIOXO-45910-DISECOA
# o_CPD-13756
# o_CPD-13758
# o_CPD-21415
# o_CPD-13711
# o_CPD-13712
#
# ######################################################################################################################################################
#
# 39
# i_CPD-18492
# i_CPD-19150
# i_CPD-11527
# i_CPD-11526
# i_CPD-11518
# i_CPD-11519
# i_CPD-17813
# i_CPD-17386
# i_CPD-17814
# i_CPD-19162
# i_CPD-19163
# i_CPD-17815
# i_CPD-19161
# i_CPD-15568
# i_CPD-11522
# i_CPD-11523
# i_CPD0-2117
# i_CPD0-2232
# i_CPD-12199
# o_P-COUMAROYL-COA
# o_CPD-18493
# o_CPD-11526
# o_CPD-19151
# o_CPD-11527
# o_CPD-11518
# o_CPD-11519
# o_CPD-17813
# o_CPD-17387
# o_CPD-17814
# o_3-HYDROXY-ISOVALERYL-COA
# o_CPD-19155
# o_CPD-19159
# o_CPD-17464
# o_CPD-19154
# o_CPD0-2171
# o_CPD-11522
# o_CPD-11523
# o_CPD0-2232
# o_CPD-12199
#
# ######################################################################################################################################################
#
# 38
# i_5Z-3-oxo-tetradec-5-enoyl-ACPs
# i_9Z-3-oxo-octadec-9-enoyl-ACPs
# i_7Z-3-oxo-hexadec-7-enoyl-ACPs
# i_3-Ketopimeloyl-ACP-methyl-esters
# i_b-Keto-cis-D5-dodecenoyl-ACPs
# i_3R-5Z-3-hydroxy-tetradec-5-enoyl-ACPs
# i_cis-delta9-3-oxo-montanoyl-ACPs
# i_cis-delta11-3-oxo-melissoyl-ACPs
# i_cis-delta13-3-oxo-lacceroyl-ACPs
# i_cis-delta15-3-oxo-gheddoyl-ACPs
# i_cis-delta17-3-oxo-C36-ACPs
# i_cis-delta19-3-oxo-C38-ACPs
# i_cis-delta21-3-oxo-C40-ACPs
# i_3-oxo-behenoyl-ACPs
# i_3-oxo-petroselinoyl-ACPs
# i_3-oxo-arachidoyl-ACPs
# i_cis-delta5-3-oxo-lignoceroyl-ACPs
# i_cis-delta7-3-oxo-cerotoyl-ACPs
# i_3-OXO-EICOSAPENTAENOYL-ACP
# o_3R-5Z-3-hydroxy-tetradec-5-enoyl-ACPs
# o_3R-9Z-3-hydroxy-octadec-9-enoyl-ACPs
# o_3R-7Z-3-hydroxy-hexadec-7-enoyl-ACPs
# o_5Z-3-oxo-tetradec-5-enoyl-ACPs
# o_R-3-hydroxypetroselinoyl-ACPs
# o_R-3-hydroxyarachidoyl-ACPs
# o_R-3-hydroxybehenoyl-ACPs
# o_cis-delta15-3-hydroxygheddoyl-ACPs
# o_cis-delta17-3-hydroxyC36-ACPs
# o_cis-delta21-3-hydroxyC40-ACPs
# o_3-HYDROXY-DOCOSAPENTAENOYL-ACP
# o_cis-delta9-3-hydroxymontanoyl-ACPs
# o_cis-delta7-3-hydroxycerotoyl-ACPs
# o_cis-delta13-3-hydroxylacceroyl-ACPs
# o_R-3-hydroxylignoceroyl-ACPs
# o_cis-delta11-3-hydroxymelissoyl-ACPs
# o_R-3-hydroxycerotoyl-ACPs
# o_cis-delta5-3-hydroxylignoceroyl-ACPs
# o_cis-delta19-3-hydroxyC38-ACPs
#
# ######################################################################################################################################################
#
# 37
# i_Dodecanoyl-RedQ
# i_CPD1A0-6182
# i_CPD1A0-6185
# i_CPD1A0-6187
# i_CPD-17025
# i_Holo-RedO
# i_RedO-L-proline
# i_RedO-pyrrole-2-carboxylate
# i_RedX-L-cysteine
# i_malonyl-RedN
# i_RedX-pyrrole-2-carboxylate
# i_ReN-3-oxo-3-1H-pyrrol-2-yl-propanoate
# i_CPD-17013
# i_CPD-17026
# i_RedN-ACP
# i_RedL-PKS
# i_CPD-17011
# i_CPD-17012
# o_RedQ-ACP
# o_CPD1A0-6185
# o_RedL-PKS
# o_CPD1A0-6187
# o_CPD-17026
# o_CPD1A0-6177
# o_RedO-L-proline
# o_RedO-pyrrole-2-carboxylate
# o_Holo-RedO
# o_RedX-pyrrole-2-carboxylate
# o_ReN-3-oxo-3-1H-pyrrol-2-yl-propanoate
# o_RedX-L-cysteine
# o_CPD-17011
# o_RedN-ACP
# o_CPD-17025
# o_malonyl-RedN
# o_CPD1A0-6182
# o_CPD-17012
# o_CPD-17013
#
# ######################################################################################################################################################
#
# 36
# i_CPD-22658
# i_DIMETHYLARSINOUS-ACID
# i_Dimethylarsenite-Arsenite-Methyltranferase
# i_METHYLARSONITE
# i_CPD-22659
# i_CPD-24372
# i_CPD-24334
# i_CPD-24369
# i_CPD-24370
# i_Arsenite-methyltransferases
# i_Arsenite-Arsenite-Methyltranferase
# i_Methylarsenite-Arsenite-Methyltranferase
# i_METHYLARSONATE
# i_CPD-24361
# i_DIMETHYLARSINATE
# i_CPD-24362
# i_CPD-24371
# o_DIMETHYLARSINATE
# o_Arsenite-methyltransferases
# o_CPD-22659
# o_CPD-24323
# o_CPD-22660
# o_METHYLARSONITE
# o_CPD-24371
# o_CPD-24334
# o_CPD-24370
# o_CPD-24324
# o_CPD-24367
# o_Arsenite-Arsenite-Methyltranferase
# o_Methylarsenite-Arsenite-Methyltranferase
# o_METHYLARSONATE
# o_CPD-24361
# o_CPD-24362
# o_CPD-24368
# o_DIMETHYLARSINOUS-ACID
# o_Dimethylarsenite-Arsenite-Methyltranferase
#
# ######################################################################################################################################################
#
# 35
# i_HYDRPHENYLAC-CPD
# i_5-HYDROXYINDOLE_ACETALDEHYDE
# i_CPD-11670
# i_CPD-7036
# i_CPD-7037
# i_CPD-7031
# i_CPD-7032
# i_CPD-7033
# i_METHYLBUT-CPD
# i_3-INDOLYLGLYCOLALDEHYDE
# i_INDOLE-3-GLYCOL
# i_CPD-11671
# i_CPD-11497
# i_CPD-11876
# i_CPD3O-4151
# i_ISOBUTANOL
# i_CPD-11878
# i_DIHYDROXYPHENYLGLYCOLALDEHYDE
# o_CPD-11876
# o_DIHYDROXYPHENYLGLYCOLALDEHYDE
# o_5-HYDROXYINDOLE_ACETALDEHYDE
# o_CPD-11670
# o_CPD-7036
# o_CPD-7037
# o_CPD-7031
# o_CPD-7032
# o_CPD-7033
# ...
#
# 6
# i_Chitodextrins
# i_CHITIN
# o_CHITOBIOSE
# o_CPD-13227
# o_Chitodextrins
# c_Chitodextrins
#
# ######################################################################################################################################################
#
# 6
# i_Primary-Alcohols
# i_Secondary-Alcohols
# i_LONG-CHAIN-KETONE
# o_Primary-Alcohols
# o_Secondary-Alcohols
# o_LONG-CHAIN-KETONE
#
# ######################################################################################################################################################
#
# 6
# i_CPD-19775
# i_CPD-17063
# i_CPD-19776
# o_CPD-19776
# o_CPD-19775
# o_CPD-13734
#
# ######################################################################################################################################################
#
# 6
# i_2-CHLOROMALEYLACETATE
# i_CPD-19731
# i_CPD-10637
# i_CPD-19732
# o_CPD-19731
# o_CPD-19732
#
# ######################################################################################################################################################
#
# 6
# i_CPD-21419
# i_CPD-13758
# i_CPD-21415
# o_CPD-21420
# o_CPD-21411
# o_CPD-21416
#
# ######################################################################################################################################################
#
# 6
# i_DITP
# i_DIMP
# i_ITP
# o_DITP
# o_XTP
# o_DIMP
#
# ######################################################################################################################################################
#
# 6
# i_CPD-9866
# i_CPD-9857
# i_CPD-9865
# o_CPD-9870
# o_CPD-9858
# o_CPD-9869
#
# ######################################################################################################################################################
#
# 6
# i_CPD-19147
# i_CPD-19148
# o_CPD-19163
# o_CPD-19162
# o_CPD-19161
# o_CPD-19150
#
# ######################################################################################################################################################
#
# 6
# i_SQUALENE
# i_CPD-14522
# i_HOP-2229-ENE
# o_SQUALENE
# o_CPD-14522
# o_HOP-2229-ENE
#
# ######################################################################################################################################################
#
# 6
# i_L-THREO-3-METHYL-ASPARTATE
# i_S-CITRAMALATE
# i_MESACONATE
# o_L-THREO-3-METHYL-ASPARTATE
# o_MESACONATE
# o_S-CITRAMALATE
#
# ######################################################################################################################################################
#
# 6
# i_CPD-721
# i_CPD-13530
# i_CPD-8486
# o_CPD-13530
# o_CPD-185
# o_CPD-721
#
# ######################################################################################################################################################
#
# 6
# i_OXALATE
# i_OXALYL-COA
# i_FORMYL-COA
# o_OXALATE
# o_OXALYL-COA
# o_FORMYL-COA
#
# ######################################################################################################################################################
#
# 6
# i_Alpha-D-Galactosides
# i_CPD-170
# i_CPD0-2500
# i_CPD-1099
# o_ALPHA-D-GALACTOSE
# o_CPD-1099
#
# ######################################################################################################################################################
#
# 6
# i_TAGATOSE-1-6-DIPHOSPHATE
# i_CPD-15826
# i_TAGATOSE-6-PHOSPHATE
# o_TAGATOSE-1-6-DIPHOSPHATE
# o_CPD-15826
# o_TAGATOSE-6-PHOSPHATE
#
# ######################################################################################################################################################
#
# 6
# i_Reduced-PrdC-Proteins
# i_D-PROLINE
# i_Oxidized-PrdC-Proteins
# o_D-PROLINE
# o_Oxidized-PrdC-Proteins
# o_Reduced-PrdC-Proteins
#
# ######################################################################################################################################################
#
# 6
# i_ACETYL-ETCETERA-GLUCOSAMINYLDIPHOSPHOUND
# i_CPD-606
# i_CPD-5802
# o_ACETYL-ETCETERA-GLUCOSAMINYLDIPHOSPHOUND
# o_CPD-606
# o_CPD-5802
#
# ######################################################################################################################################################
#
# 6
# i_CPD-15616
# i_CPD-9569
# i_CPD-369
# o_CPD-15616
# o_CPD-9569
# o_CPD-369
#
# ######################################################################################################################################################
#
# 6
# i_N-ACETYL-D-MANNOSAMINE
# i_CPD-1109
# i_CPD-841
# o_N-ACETYL-D-MANNOSAMINE
# o_CPD-1109
# o_CPD-841
#
# ######################################################################################################################################################
#
# 6
# i_CPD-15976
# i_CELLOBIOSE
# i_CPD-15975
# o_CPD-16157
# o_CPD-507
# o_CPD-15978
#
# ######################################################################################################################################################
#
# 6
# i_CPD1F-129
# i_CPD-7850
# i_CPD1F-130
# o_CPD-7849
# o_CPD-7847
# o_CPD-7850
#
# ######################################################################################################################################################
#
# 6
# i_CPD-14423
# i_CPD-14422
# i_CPD-375
# o_CPD-14424
# o_CPD-14419
# o_CPD-375
#
# ######################################################################################################################################################
#
# 6
# i_CPD-641
# i_CPD-499
# i_MEVALONATE
# o_CPD-499
# o_MEVALONATE
# o_CPD-641
#
# ######################################################################################################################################################
#
# 6
# i_CPD-12707
# i_CPD-12708
# o_CPD-12708
# o_CPD-12710
# o_CPD-12707
# o_CPD-12709
#
# ######################################################################################################################################################
#
# 6
# i_CIS-3-HEXENAL
# i_TRANS-2-HEXENAL
# i_TRANS-2-HEXENOL
# o_CIS-3-HEXENAL
# o_TRANS-2-HEXENAL
# o_TRANS-2-HEXENOL
#
# ######################################################################################################################################################
#
# 6
# i_CPD-458
# i_CPD-8058
# i_4-METHYL-MYO-INOSITOL
# o_CPD-458
# o_CPD-8058
# o_4-METHYL-MYO-INOSITOL
#
# ######################################################################################################################################################
#
# 6
# i_L-DIHYDROXY-PHENYLALANINE
# i_CPD-253
# i_CPD-8651
# o_CPD-8651
# o_CPD-8670
# o_CPD-253
#
# ######################################################################################################################################################
#
# 6
# i_Lysophospholipids
# i_N-arachidonoyl-2-lyso-PE
# i_N-Arachidonoyl-1-lyso-PE
# i_2-Acylglycero-Phosphocholines
# o_Glycerophosphodiesters
# o_CPD-22238
#
# ######################################################################################################################################################
#
# 6
# i_apo-Transcarboxylases
# i_3-methylcrotonoyl-CoA-carboxylase-lysine
# i_Apo-Propionyl-CoA-CO2-ligases
# o_holo-Transcarboxylases
# o_Biotin-EC6-4-1-4
# o_Propionyl-CoA-CO2-ligases
#
# ######################################################################################################################################################
#
# 6
# i_L-FUCULOSE
# i_CPD0-1107
# i_CPD-10329
# o_FUCULOSE-1P
# o_CPD-10329
# o_L-FUCULOSE
#
# ######################################################################################################################################################
#
# 6
# i_Sphingoids
# i_SPHINGOSINE
# i_CPD-13612
# o_Sphingoids
# o_SPHINGOSINE
# o_CPD-13612
#
# ######################################################################################################################################################
#
# 6
# i_D-altropyranoses
# i_ALTROSE
# i_PSICOSE
# o_D-altropyranoses
# o_ALTROSE
# o_PSICOSE
#
# ######################################################################################################################################################
#
# 6
# i_N-ACETYL-D-GLUCOSAMINE-16-BIS-P
# i_Phosphoacetylglucosamine-Mutase-P
# i_Phosphoacetylglucosamine-Mutase
# o_N-ACETYL-D-GLUCOSAMINE-16-BIS-P
# o_Phosphoacetylglucosamine-Mutase-P
# o_Phosphoacetylglucosamine-Mutase
#
# ######################################################################################################################################################
#
# 6
# i_3-MERCAPTO-PYRUVATE
# i_TUM1-S-sulfanylcysteine
# i_TUM1-L-cysteine
# o_TUM1-L-cysteine
# o_3-MERCAPTO-PYRUVATE
# o_TUM1-S-sulfanylcysteine
#
# ######################################################################################################################################################
#
# 6
# i_FRUCTOSELYSINE
# i_PSICOSELYSINE
# i_FRUCTOSELYSINE-6-PHOSPHATE
# o_FRUCTOSELYSINE-6-PHOSPHATE
# o_PSICOSELYSINE
# o_FRUCTOSELYSINE
#
# ######################################################################################################################################################
#
# 6
# i_Pre-tRNA-3-prime-half-molecules
# i_Pre-tRNA-5-prime-half-molecules
# i_ligated-tRNAs-with-2prime-5prime-linkage
# o_Pre-tRNA-3-prime-half-molecules
# o_Pre-tRNA-5-prime-half-molecules
# o_ligated-tRNAs-with-2prime-5prime-linkage
#
# ######################################################################################################################################################
#
# 6
# i_CPD-31
# i_2-METHYLMALEATE
# i_CPD-7066
# o_2-METHYLMALEATE
# o_CPD-31
# o_CPD-7066
#
# ######################################################################################################################################################
#
# 6
# i_DFA-III
# i_INULOBIOSE
# o_Charged-D-Ala-Carrier-Proteins
# o_DFA-III
# o_INULOBIOSE
# c_Inulin
#
# ######################################################################################################################################################
#
# 6
# i_CPD-9409
# i_CPD-9408
# i_CPD-208
# o_CPD-208
# o_CPD-9408
# o_CPD-9409
#
# ######################################################################################################################################################
#
# 6
# i_CPD-514
# i_CINNAMOYL-COA
# i_CPD-513
# o_BENZOYLCOA
# o_CPD-513
# o_CPD-514
#
# ######################################################################################################################################################
#
# 6
# i_3-oxopimeloyl-ACPs
# i_Enoyl-Pimeloyl-ACPs
# i_3R-hydroxy-Pimeloyl-ACPs
# o_3R-hydroxy-Pimeloyl-ACPs
# o_3-oxopimeloyl-ACPs
# o_Enoyl-Pimeloyl-ACPs
#
# ######################################################################################################################################################
#
# 6
# i_CPD-821
# i_CPD-17175
# i_CPD-904
# o_CPD-904
# o_CPD-17175
# o_CPD-821
#
# ######################################################################################################################################################
#
# 6
# i_N1-METHYLADENINE
# i_an-Nsup3sup-methylcytosine-in-DNA
# i_an-Nsup1sup-methyladenine-in-DNA
# i_CPD-20036
# i_CPD-20035
# o_DNA-Adenines
#
# ######################################################################################################################################################
#
# 6
# i_Steryl-Esters
# i_CPD-16016
# i_CPD-16017
# o_Sterols
# o_LANOSTEROL
# o_ERGOSTEROL
#
# ######################################################################################################################################################
#
# 6
# i_CPD-18761
# i_CPD-15172
# i_CPD-8890
# i_a-radical-of-luteolin-7-iOi-diglucuronid
# o_CPD-12724
# o_CPD-8653
#
# ######################################################################################################################################################
#
# 6
# i_Alkyl-enyl-acyl-gly-P-EtOH-amines
# i_PLASMENYLCHOLINE
# o_Alkyl-enyl-acyl-gly-P-EtOH-amines
# o_PHOSPHORYL-ETHANOLAMINE
# o_1-ALKENYL-2-ACYLGLYCEROL
# o_1-Alkenyl-glycerol
#
# ######################################################################################################################################################
#
# 6
# i_1-2-DIPALMITOYLPHOSPHATIDYLCHOLINE
# i_Glycerolipids
# i_CPD-17282
# o_CPD-8343
# o_Glycerolipids
# o_CPD-17282
#
# ######################################################################################################################################################
#
# 6
# i_HypE-Proteins
# i_HypE-S-carboxamide
# i_CPD-15424
# o_HypE-S-carboxamide
# o_HypE-S-cyanate
# o_CPD-15424
#
# ######################################################################################################################################################
#
# 6
# i_a-reduced-TorC-protein
# i_TRIMETHYLAMINE-N-O
# i_A-REDUCED-TORY-PROTEIN
# o_TRIMETHYLAMINE
# o_an-oxidized-TorC-protein
# o_an-oxidized-TorY-protein
#
# ######################################################################################################################################################
#
# 6
# i_HEXANOATE
# i_Ala-tRNA-Pro
# i_9-Decenoyl-ACPs
# o_5-hexynoyl-ACPs
# o_9-Decenoyl-ACPs
# o_9-Decynoyl-ACPs
#
# ######################################################################################################################################################
#
# 6
# i_CPD-15867
# o_CPD-15868
# o_CPD-15867
# c_CPD0-1113
# c_CPD-13227
# c_CPD-15867
#
# ######################################################################################################################################################
#
# 6
# i_CPD-18478
# i_CPD-10622
# i_CPD-10635
# o_CPD-10636
# o_CPD-10635
# o_CPD-18478
#
# ######################################################################################################################################################
#
# 6
# i_CPD-11740
# i_1-CARBOXYVINYL-CARBOXYPHOSPHONATE
# i_3-HYDROHYDROXYPHOSPHORYLPYRUVATE
# o_CPD-11740
# o_1-CARBOXYVINYL-CARBOXYPHOSPHONATE
# o_3-HYDROHYDROXYPHOSPHORYLPYRUVATE
#
# ######################################################################################################################################################
#
# 6
# i_CPD-13149
# i_CPD-20451
# i_CPD-13150
# o_CPD-13151
# o_CPD-13150
# o_CPD-20451
#
# ######################################################################################################################################################
#
# 6
# i_CPD-24744
# i_CPD-24745
# i_CPD-24746
# o_CPD-24745
# o_CPD-24746
# o_CPD-24744
#
# ######################################################################################################################################################
#
# 5
# i_Lipoyl-Protein-L-Lysine
# i_LIPOYL-AMP
# i_LIPOIC-ACID
# o_Lipoyl-Protein-N6-lipoyllysine
# o_LIPOYL-AMP
#
# ######################################################################################################################################################
#
# 5
# i_HOMOGENTISATE
# i_4-FUMARYL-ACETOACETATE
# o_4-FUMARYL-ACETOACETATE
# o_4-MALEYL-ACETOACETATE
# o_HOMOGENTISATE
#
# ######################################################################################################################################################
#
# 5
# i_CPD-4
# i_CPD-8123
# i_CPD-15874
# o_CPD-582
# o_CPD-15874
#
# ######################################################################################################################################################
#
# 5
# i_CPD-21429
# i_CPD-12151
# o_CPD-21428
# o_CPD-21429
# c_CPD-21428
#
# ######################################################################################################################################################
#
# 5
# i_CPD-470
# i_N-ACETYL-L-24-DIAMINOBUTANOATE
# i_ECTOINE
# o_N-ACETYL-L-24-DIAMINOBUTANOATE
# o_ECTOINE
#
# ######################################################################################################################################################
#
# 5
# i_CPD-15124
# i_CPD-10824
# o_CPD-10824
# o_CPD-10825
# o_CPD-15124
#
# ######################################################################################################################################################
#
# 5
# i_CPD-16567
# i_RHAMNULOSE-1P
# o_RHAMNULOSE-1P
# o_CPD-16567
# o_CPD-16566
#
# ######################################################################################################################################################
#
# 5
# i_Ribulose-phosphates
# i_L-RIBULOSE
# o_L-RIBULOSE-5-P
# o_Ribulose-phosphates
# o_L-RIBULOSE
#
# ######################################################################################################################################################
#
# 5
# i_CPD-19306
# i_D-alanine-carrier-protein
# i_CPD-19311
# o_CPD-19306
# o_CPD-19305
#
# ######################################################################################################################################################
#
# 5
# i_CPD-15978
# i_CPD0-2499
# i_CPD0-2501
# o_N-ACETYL-D-GLUCOSAMINE-6-P
# o_CPD0-2501
#
# ######################################################################################################################################################
